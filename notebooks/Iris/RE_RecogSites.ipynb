# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import datetime
import os
print(datetime.datetime.now())
# Out:
# 2019-09-12 17:01:14.132029

# %%
from pygentoolbox.CountRESites import main_CountRESites
# Out:
# Enter full path to file:  D:\\LinuxShare\\Ciliates\\Genomes\\Seqs\\ptetraurelia_mac_51.fa
# Enter restriction enzyme pattern, ex. GATC:  GATC
# D:\\LinuxShare\\Ciliates\\Genomes\\Seqs\\ptetraurelia_mac_51.fa
# Number of sequences: 697
# Number of RE sites matching GATC: 213181
# Expected number of RE recognition sites for sequence of length 72102941 and pattern of length 4 = 281652
# Cuttting efficiency = 0.900000
# [1228, 53, 32, 666, 222, 1127, 455, 1329, 483, 40, 126, 625, 1444, 171, 867, 33, 30, 185, 721, 854, 130, 1232, 140, 136, 393, 241, 433, 455, 521, 564, 467, 155, 335, 162, 400, 139, 188, 1206, 208, 1169, 29, 196, 168, 210, 322, 291, 1082, 886, 689, 101, 103, 63, 190, 258, 839, 1263, 862, 44, 635, 675, 28, 705, 617, 236, 314, 57, 334, 273, 462, 42, 655, 216, 186, 192, 11, 458, 972, 194, 351, 4, 24, 42, 157, 618, 264, 184, 150, 393, 1520, 590, 325, 858, 159, 2257, 277, 585, 761, 676, 65, 78]
# Mean of fragment size: 373.678184
# Mean of mean fragment size > 1000: 1437.310187
# Mean of mean fragment size > 2000: 2563.856727

# %%
main_CountRESites()
# Out:
# Enter full path to file:  D:\\LinuxShare\\Ciliates\\Genomes\\Seqs\\ptetraurelia_mac_51_with_ies.fa
# Enter restriction enzyme pattern, ex. GATC:  GATC
# D:\\LinuxShare\\Ciliates\\Genomes\\Seqs\\ptetraurelia_mac_51_with_ies.fa
# Number of sequences: 697
# Number of RE sites matching GATC: 218732
# Expected number of RE recognition sites for sequence of length 75658061 and pattern of length 4 = 295539
# Cuttting efficiency = 0.900000
# [1228, 53, 32, 510, 378, 1622, 455, 1329, 483, 40, 126, 1780, 289, 171, 867, 33, 30, 185, 1575, 130, 1232, 140, 136, 393, 174, 67, 433, 455, 1085, 622, 497, 400, 139, 188, 451, 755, 672, 705, 29, 63, 133, 168, 210, 322, 291, 1082, 886, 689, 101, 103, 511, 839, 1263, 862, 44, 635, 63, 612, 28, 705, 315, 302, 236, 314, 57, 334, 273, 462, 42, 871, 186, 192, 11, 523, 774, 198, 194, 351, 4, 24, 42, 157, 1015, 184, 150, 393, 523, 56, 1845, 325, 858, 159, 1608, 721, 277, 585, 837, 676, 65, 78]
# Mean of fragment size: 382.642533
# Mean of mean fragment size > 1000: 1445.146849
# Mean of mean fragment size > 2000: 2558.423879

# %%
main_CountRESites()
# Out:
# Enter full path to file:  D:\\LinuxShare\\Ciliates\\Genomes\\Seqs\\ptetraurelia_mic2.fa
# Enter restriction enzyme pattern, ex. GATC:  GATC
# D:\\LinuxShare\\Ciliates\\Genomes\\Seqs\\ptetraurelia_mic2.fa
# Number of sequences: 26186
# Number of RE sites matching GATC: 270788
# Expected number of RE recognition sites for sequence of length 98489268 and pattern of length 4 = 384723
# Cuttting efficiency = 0.900000
# [350, 143, 242, 353, 488, 1515, 161, 228, 270, 20, 750, 76, 27, 155, 312, 786, 437, 783, 8, 577, 229, 612, 78, 192, 194, 112, 1207, 2141, 446, 754, 256, 1141, 1280, 871, 58, 277, 63, 249, 315, 284, 565, 45, 270, 393, 1218, 35, 736, 653, 111, 855, 281, 358, 248, 469, 105, 94, 160, 151, 440, 250, 5, 177, 603, 286, 369, 38, 1447, 31, 36, 351, 54, 26, 202, 607, 1105, 588, 26, 602, 208, 268, 325, 27, 93, 72, 36, 16, 383, 931, 27, 230, 790, 408, 476, 558, 80, 234, 82, 313, 13, 624]
# Mean of fragment size: 374.032775
# Mean of mean fragment size > 1000: 1423.418056
# Mean of mean fragment size > 2000: 2432.508822
