# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
import pandas as pd
print(datetime.datetime.now())

#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
from pygentoolbox.IRS_v2 import main
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2019-09-23 14:09:14.966228

# %%
# i ran the TrimSam_TrimGff3 notebook before this to limit IES features and sam aligned sequences to scaffold51_1
# 588 features
gff3file = 'D:\\LinuxShare\\Ciliates\\Genomes\\Annotations\\internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.TrimScaffolds.gff3'
# 1008727 sequences
samfilelist_mac = ['D:\\LinuxShare\\Projects\\Sarah\\BWA\\DCL_SCG\\Mac\\D23_1_R1R2.trim.TrimScaffolds.sam', ]
# 1029507 sequences
samfilelist_mac_ies = ['D:\\LinuxShare\\Projects\\Sarah\\BWA\\DCL_SCG\\MacAndIES\\D23_1_R1R2.trim.sort.TrimScaffolds.sam']

main(gff3file, samfilelist_mac, samfilelist_mac_ies, numreads=500000, features=['internal_eliminated_sequence'])  # or use ['all']

print(datetime.datetime.now())
# Out:
# Reading Gff3 file: D:\LinuxShare\Ciliates\Genomes\Annotations\internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.TrimScaffolds.gff3
# Number of scaffolds: 1
# ['scaffold51_1']
# Reading, sub-sampling, trim by CIGAR, only coordinates,  for sam file: D:\LinuxShare\Projects\Sarah\BWA\DCL_SCG\Mac\D23_1_R1R2.trim.TrimScaffolds.sam
# Number of scaffolds: 1
# ['scaffold51_1']
# Desired Number of reads: 500000
# Number of sub-sampled reads = 317367
# Reading, sub-sampling, trim by CIGAR, only coordinates,  for sam file: D:\LinuxShare\Projects\Sarah\BWA\DCL_SCG\MacAndIES\D23_1_R1R2.trim.sort.TrimScaffolds.sam
# Number of scaffolds: 1
# ['scaffold51_1']
# Desired Number of reads: 500000
# Number of sub-sampled reads = 293925
# ##### Starting IRS Calculations #####
# scaffold51_1 is present in d_mac, dsam_mac, and dsam_mac_ies
# Calculating IRS
# IRS 10
# 0, 0, 3, 45
# IESPGM.PTET51.1.1.7378 0.00, 0.06
# IRS 20
# 1, 1, 0, 41
# IESPGM.PTET51.1.1.12301 0.02, 0.05
# IRS 30
# 0, 1, 0, 22
# ...
