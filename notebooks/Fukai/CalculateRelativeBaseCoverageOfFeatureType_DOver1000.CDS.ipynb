# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox.CalculateRelativeBaseCoverageOfFeatureType import main
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2019-07-31 15:32:09.381667

# %%
Gff3file = 'D:\\LinuxShare\\Ciliates\\Genomes\\Annotations\\ptetraurelia_mac_51_annotation_v2.0.gff3'
samfilelist = ['D:\\LinuxShare\\Projects\\Theresa\\Hisat2\\FlagHA_Pt08\\Pt_51_Mac\\52_Late.Uniq.23M.sort.windows.100.sam', 'D:\\LinuxShare\\Projects\\Theresa\\Hisat2\\FlagHA_Pt08\\Pt_51_Mac\\53_Later.Uniq.23M.sort.windows.100.sam']
target_feature = 'CDS'

# plots histograms of all relative positions for all features of a feature type
# relative position for each gene (1st position = 1/len(gene), 5th = 5/len(gene))
# i.e. normalizes each position in feature by gene length

main(Gff3file, samfilelist, target_feature)
# Out:
# Reading Gff3 file: D:\LinuxShare\Ciliates\Genomes\Annotations\ptetraurelia_mac_51_annotation_v2.0.gff3
# Number of scaffolds: 539
# Reading sam file: D:\LinuxShare\Projects\Theresa\Hisat2\FlagHA_Pt08\Pt_51_Mac\52_Late.Uniq.23M.sort.windows.100.sam
# Number of scaffolds: 697
# Total number of lines in sam file (excluding header): 1576021
# For each position in feature: CDS, normalize by gene length, record value for histogram
# Summary of feature: CDS, Number of features: 135171, Mean length: 397.21
# Plotting histogram to outfile: D:\LinuxShare\Projects\Theresa\Hisat2\FlagHA_Pt08\Pt_51_Mac\52_Late.Uniq.23M.sort.windows.100.NormCov.CDS.pdf
# Reading sam file: D:\LinuxShare\Projects\Theresa\Hisat2\FlagHA_Pt08\Pt_51_Mac\53_Later.Uniq.23M.sort.windows.100.sam
# Number of scaffolds: 697
# Total number of lines in sam file (excluding header): 1463537
# For each position in feature: CDS, normalize by gene length, record value for histogram
# ...
