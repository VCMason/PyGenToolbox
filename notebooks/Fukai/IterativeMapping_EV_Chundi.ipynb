# %%
# %load_ext autoreload
# %autoreload 2
import os
import glob
import datetime
import subprocess
print(datetime.datetime.now())

from pygentoolbox import ReadMapping
from pygentoolbox import ReadMapping_v2

from pygentoolbox import SeqsPerFeatureAndFeatureTypeFixed
from pygentoolbox import CalculateRelativeBaseCoverageOfFeatureType

# need pygentoolbox.Tools also
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2021-05-25 17:07:49.259273

# %%
# define variables:
# cell 1
# forward = ['Ptiwi09_RIP_Early25bp25bp.fastq.gz']
forward = ['EV_E1_L12_R1.fastq.gz', 'EV_E2_L12_R1.fastq.gz']
#for i in range(15, 42): # align each seq length 15-41 and then 50bps # this is EV_late_totalsRNA
#    name = f'190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_{i}bp.fastq.gz'
#    forward.append(name)
#forward.append('190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_50bp.fastq.gz')
reverse = ['EV_E1_L12_R2.fastq.gz', 'EV_E1_L12_R2.fastq.gz']
#reverse = [''] * len(forward)
#forward = ['H3K4me3_Rep1_R1.fastq.gz', 'H3K4me3_Rep2_R1.fastq.gz', 'H3K9me3_Rep1_R1.fastq.gz', 'H3K9me3_Rep2_R1.fastq.gz', 'H3K27me3_Rep1_R1.fastq.gz', 'H3K27me3_Rep2_R1.fastq.gz']
#reverse = ['H3K4me3_Rep1_R2.fastq.gz', 'H3K4me3_Rep2_R2.fastq.gz', 'H3K9me3_Rep1_R2.fastq.gz', 'H3K9me3_Rep2_R2.fastq.gz', 'H3K27me3_Rep1_R2.fastq.gz', 'H3K27me3_Rep2_R2.fastq.gz']
directory='/media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac'
cleanreads=False  # are .fastq.gz reads already clean? if True skip fastp
paired=True
reference='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac'

skipsteps=[]
hisat_args='-p2'
#hisat_args='-p2 --no-softclip'
#hisat_args='-p 2 --no-softclip --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'

# %%
#fileextension='.fastq.gz'
#directory='/media/sf_LinuxShare/Projects/Ryuma/hisat2/2018-09-19_L1-4_ADPF-29_inserts'
#cleanreads=True  # are .fastq.gz reads already clean? if True skip fastp
#reference='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac'
print(datetime.datetime.now())

ReadMapping_v2.main(forward, reverse, directory, hisat_args, skipsteps, paired, reference)

print(datetime.datetime.now())
# Out:
# 2021-05-25 17:07:57.225532
# Start trimming of:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/EV_E1_L12_R1.fastq.gz
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/EV_E1_L12_R2.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp  already exists
# Directory  /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp  already exists
# fastp -i /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/EV_E1_L12_R1.fastq.gz -I /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/EV_E1_L12_R2.fastq.gz -o /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R1.trim.fastq.gz -O /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq.gz
# b''
# Finished trimming, files output to:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R1.trim.fastq.gz
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq.gz
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R1.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R1.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R1.trim.fastq
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc
# Directory  /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc  already exists
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R1.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc
# Directory  /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc  already exists
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc
#
# Aligning reads to Reference:
# /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac
# Directory  /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/hisat2  already exists
# Starting Hisat2 paired end: aligning
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R1.trim.fastq.gz, /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq.gz
# hisat2 -q -p2 -x /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac -1 /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R1.trim.fastq.gz -2 /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq.gz -S /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/hisat2/EV_E1_L12_R1.trim.Pt_51_Mac.sam
# Finished with Hisat2
#
# Starting samtools converting sam to sorted indexed bam
# Finished with Samtools, returning /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/hisat2/EV_E1_L12_R1.trim.Pt_51_Mac.sort.bam
#
# Start trimming of:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/EV_E2_L12_R1.fastq.gz
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/EV_E1_L12_R2.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp  already exists
# Directory  /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp  already exists
# fastp -i /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/EV_E2_L12_R1.fastq.gz -I /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/EV_E1_L12_R2.fastq.gz -o /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E2_L12_R1.trim.fastq.gz -O /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq.gz
# b''
# Finished trimming, files output to:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E2_L12_R1.trim.fastq.gz
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq.gz
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E2_L12_R1.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E2_L12_R1.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E2_L12_R1.trim.fastq
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc
# Directory  /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc  already exists
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E2_L12_R1.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc
# Directory  /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc  already exists
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/fastqc
#
# Aligning reads to Reference:
# /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac
# Directory  /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/hisat2  already exists
# Starting Hisat2 paired end: aligning
# /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E2_L12_R1.trim.fastq.gz, /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq.gz
# hisat2 -q -p2 -x /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac -1 /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E2_L12_R1.trim.fastq.gz -2 /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/EV_E1_L12_R2.trim.fastq.gz -S /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/hisat2/EV_E2_L12_R1.trim.Pt_51_Mac.sam
# Finished with Hisat2
#
# Starting samtools converting sam to sorted indexed bam
# Finished with Samtools, returning /media/sf_LinuxShare/Projects/Fukai/Hisat2/Chundi_EV/Pt_51_Mac/fastp/hisat2/EV_E2_L12_R1.trim.Pt_51_Mac.sort.bam
#
# ##########
# ###FIN####
# ##########
# 2021-05-26 01:24:45.999320

# %%
# %load_ext autoreload
# %autoreload 2
import os
import glob
import datetime
import subprocess
print(datetime.datetime.now())

from pygentoolbox import ReadMapping
from pygentoolbox import ReadMapping_v2
from pygentoolbox import SplitFastqFileBySeqLength

from pygentoolbox import SeqsPerFeatureAndFeatureTypeFixed
from pygentoolbox import CalculateRelativeBaseCoverageOfFeatureType

# need pygentoolbox.Tools also
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2021-02-12 12:26:36.276854

# %%
# define variables:
# cell 1
# forward = ['Ptiwi09_RIP_Early25bp25bp.fastq.gz']
forward = ['190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And22bp.fastq.gz', '190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And24bp.fastq.gz']
reverse = [''] * len(forward)
#forward = ['H3K4me3_Rep1_R1.fastq.gz', 'H3K4me3_Rep2_R1.fastq.gz', 'H3K9me3_Rep1_R1.fastq.gz', 'H3K9me3_Rep2_R1.fastq.gz', 'H3K27me3_Rep1_R1.fastq.gz', 'H3K27me3_Rep2_R1.fastq.gz']
#reverse = ['H3K4me3_Rep1_R2.fastq.gz', 'H3K4me3_Rep2_R2.fastq.gz', 'H3K9me3_Rep1_R2.fastq.gz', 'H3K9me3_Rep2_R2.fastq.gz', 'H3K27me3_Rep1_R2.fastq.gz', 'H3K27me3_Rep2_R2.fastq.gz']
directory='/media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac'
cleanreads=False  # are .fastq.gz reads already clean? if True skip fastp
paired=False
reference='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac'

skipsteps=[]
hisat_args='-p2 --no-softclip'
#hisat_args='-p 2 --no-softclip --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'

# %%
#fileextension='.fastq.gz'
#directory='/media/sf_LinuxShare/Projects/Ryuma/hisat2/2018-09-19_L1-4_ADPF-29_inserts'
#cleanreads=True  # are .fastq.gz reads already clean? if True skip fastp
#reference='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac'
print(datetime.datetime.now())

ReadMapping_v2.main(forward, reverse, directory, hisat_args, skipsteps, paired, reference)

print(datetime.datetime.now())
# Out:
# 2021-02-12 12:28:51.058352
# Start trimming of:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And22bp.fastq.gz
#
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp  already exists
# fastp -i /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And22bp.fastq.gz -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And22bp.trim.fastq.gz
# b''
# Finished trimming, files output to:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And22bp.trim.fastq.gz
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And22bp.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And22bp.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And22bp.trim.fastq
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/fastqc
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/fastqc  already exists
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And22bp.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/fastqc
#
# Aligning reads to Reference:
# /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/hisat2  already exists
# Starting Hisat2 single end: aligning
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And22bp.trim.fastq.gz
# hisat2 -q -p2 --no-softclip -x /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac -U /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And22bp.trim.fastq.gz -S /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/hisat2/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And22bp.trim.Pt_51_Mac.sam
# Finished with Hisat2
#
# Starting samtools converting sam to sorted indexed bam
# Finished with Samtools, returning /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/hisat2/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And22bp.trim.Pt_51_Mac.sort.bam
#
# Start trimming of:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And24bp.fastq.gz
#
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp  already exists
# fastp -i /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And24bp.fastq.gz -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And24bp.trim.fastq.gz
# b''
# Finished trimming, files output to:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And24bp.trim.fastq.gz
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And24bp.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And24bp.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And24bp.trim.fastq
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/fastqc
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/fastqc  already exists
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And24bp.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/fastqc
#
# Aligning reads to Reference:
# /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/hisat2  already exists
# Starting Hisat2 single end: aligning
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And24bp.trim.fastq.gz
# hisat2 -q -p2 --no-softclip -x /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac -U /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And24bp.trim.fastq.gz -S /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/hisat2/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And24bp.trim.Pt_51_Mac.sam
# Finished with Hisat2
#
# Starting samtools converting sam to sorted indexed bam
# Finished with Samtools, returning /media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/hisat2/190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_23And24bp.trim.Pt_51_Mac.sort.bam
#
# ##########
# ###FIN####
# ##########
# 2021-02-12 12:29:44.494259
