# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox.CalculateRelativeBaseCoverageOfFeatureType import main
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2021-01-14 16:59:36.884818

# %%
gff3file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
filelist = ['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.pt.wthickness.Win300.MQ10.NormDPNII.txt', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.pt.wthickness.Win300.MQ10.NormDPNII.txt', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_50MilReads/hisat2/Pt_51_MacAndIES/RNA.DNA.Contacts.pt.wthickness.Win300.MQ0.NormDPNII.tsv']
datatype='contacts' # options 'sam', 'contacts', 'bed'
target_feature = 'internal_eliminated_sequence'
numbins = 50

# plots histograms of all relative positions for all features of a feature type
# relative position for each gene (1st position = 1/len(gene), 5th = 5/len(gene))
# i.e. normalizes each position in feature by gene length

main(gff3file, filelist, datatype, target_feature, numbins)
# Out:
# Reading Gff3 file: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Number of scaffolds: 511
# Reading contact file: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.pt.wthickness.Win300.MQ10.NormDPNII.txt
# Gathering DNA contact position and strength
# Number of total contacts: 8513261
# Number of uniqe contacts: 3084594
# For each position in feature: internal_eliminated_sequence, normalize by gene length, record value for histogram
# Plotting histogram to outfile: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.pt.wthickness.Win300.MQ10.NormDPNII.NormCov.internal_eliminated_sequence.pdf
# Reading contact file: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.pt.wthickness.Win300.MQ10.NormDPNII.txt
# Gathering DNA contact position and strength
# Number of total contacts: 9025060
# Number of uniqe contacts: 3179606
# For each position in feature: internal_eliminated_sequence, normalize by gene length, record value for histogram
# Plotting histogram to outfile: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.pt.wthickness.Win300.MQ10.NormDPNII.NormCov.internal_eliminated_sequence.pdf
# Reading contact file: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_50MilReads/hisat2/Pt_51_MacAndIES/RNA.DNA.Contacts.pt.wthickness.Win300.MQ0.NormDPNII.tsv
# Gathering DNA contact position and strength
# Number of total contacts: 3371339
# Number of uniqe contacts: 1577018
# For each position in feature: internal_eliminated_sequence, normalize by gene length, record value for histogram
# Plotting histogram to outfile: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_50MilReads/hisat2/Pt_51_MacAndIES/RNA.DNA.Contacts.pt.wthickness.Win300.MQ0.NormDPNII.NormCov.internal_eliminated_sequence.pdf
