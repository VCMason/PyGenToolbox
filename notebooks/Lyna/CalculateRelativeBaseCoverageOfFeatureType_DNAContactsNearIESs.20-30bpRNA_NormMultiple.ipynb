# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox.CalculateRelativeBaseCoverageOfFeatureType import main
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2021-04-22 20:51:06.918270

# %%
gff3file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
filelist = ['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_sRNA20to30bps/hisat2/RNA.DNA.Contacts.pt.wthickness.Win300.MQ10.NormDPNII.txt', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_L_sRNA20to30bps/hisat2/RNA.DNA.Contacts.pt.wthickness.Win300.MQ10.NormDPNII.txt', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E_sRNA20to30bps/hisat2/RNA.DNA.Contacts.pt.wthickness.Win300.MQ10.NormDPNII.txt', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/RNA.DNA.Contacts.pt.wthickness.Win300.MQ10.NormDPNII.txt']
#filelist = ['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.pt.wthickness.Win300.MQ10.NormDPNII.txt', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.pt.wthickness.Win300.MQ10.NormDPNII.txt', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_50MilReads/hisat2/Pt_51_MacAndIES/RNA.DNA.Contacts.pt.wthickness.Win300.MQ0.NormDPNII.tsv']
datatype='contacts' # options 'sam', 'contacts', 'bed'
target_feature = 'internal_eliminated_sequence'
numbins = 50
normalizationmultiple=10
sizefactors = [1, 1, 0.58, 1.31]  # could be [1,1,1,1] if no adjustment needed

# plots histograms of all relative positions for all features of a feature type
# relative position for each gene (1st position = 1/len(gene), 5th = 5/len(gene))
# i.e. normalizes each position in feature by gene length

main(gff3file, filelist, sizefactors, datatype, target_feature, numbins, normalizationmultiple)
# Out:
# Reading Gff3 file: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Number of scaffolds: 511
# Reading contact file: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_sRNA20to30bps/hisat2/RNA.DNA.Contacts.pt.wthickness.Win300.MQ10.NormDPNII.txt
# Gathering DNA contact position and strength
# Number of total contacts: 191763
# Number of unique contacts: 191633
# For each position in feature: internal_eliminated_sequence, normalize by gene length, record value for histogram
# Number of unique contacts left of IESs: 7976
# Number of unique contacts within IESs: 203
# Number of unique contacts right of IESs: 7400
# Frequency of unique contacts left of IESs 0.04162122390193756
# Frequency of unique contacts within IESs 0.0010593165060297548
# Frequency of unique contacts right of IESs 0.03861547854492702
# ...
