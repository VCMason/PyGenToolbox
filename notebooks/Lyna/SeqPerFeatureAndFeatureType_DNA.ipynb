# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox.SeqsPerFeatureAndFeatureTypeFixed import main
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2020-07-20 17:44:22.747058

# %%
Gff3file = 'D:\\LinuxShare\\Ciliates\\Genomes\\Annotations\\ptetraurelia_mac_51_annotation_v2.0.gene.gff3'
samfilelist = ['D:\\LinuxShare\\Projects\\Lyna\\CharSeqPipe\\EV_E_50MilReads\\hisat2\\WT_E_L1_R1R2.trim.Ass50Million.DNA20RNA20.dna.NoSplice.F260.sort.sam', 'D:\\LinuxShare\\Projects\\Lyna\\CharSeqPipe\\EV_L_50MilReads\\hisat2\\WT_L_L1_R1R2.trim.assembled.lines200000000.DNA20RNA20.dna.NoSplice.F260.sort.sam']
# count number of reads per feature
# count number of reads per feature type (exon, mRNA, 5' UTR, etc.) and sort so counts are decreasing

main(Gff3file, samfilelist)
# Out:
# Reading Gff3 file: D:\LinuxShare\Ciliates\Genomes\Annotations\ptetraurelia_mac_51_annotation_v2.0.gene.gff3
# Number of scaffolds: 539
# Reading sam file: D:\LinuxShare\Projects\Lyna\CharSeqPipe\EV_E_50MilReads\hisat2\WT_E_L1_R1R2.trim.Ass50Million.DNA20RNA20.dna.NoSplice.F260.sort.sam
# Number of scaffolds (in header): 697
# Total number of lines in sam file (excluding header): 7340864
# Mapped reads, so calculating seqs per feature and feature type
# Counting reads for all feature and Count reads per feature type (ex: exon, gene, CDS, etc.)
# ...

# %%
Gff3file = 'D:\\LinuxShare\\Ciliates\\Genomes\\Annotations\\ptetraurelia_mac_51_annotation_v2.0.gene.gff3'
samfilelist = ['D:\\LinuxShare\\Projects\\Lyna\\CharSeqPipe\\EV_E_50MilReads\\hisat2\\WT_E_L1_R1R2.trim.Ass50Million.DNA20RNA20.dna.bridgePE.fastq.sort.F260.sam', 'D:\\LinuxShare\\Projects\\Lyna\\CharSeqPipe\\EV_L_50MilReads\\hisat2\\WT_L_L1_R1R2.trim.assembled.lines200000000.DNA20RNA20.dna.bridgePE.sort.F260.sam']
# count number of reads per feature
# count number of reads per feature type (exon, mRNA, 5' UTR, etc.) and sort so counts are decreasing

main(Gff3file, samfilelist)
# Out:
# Reading Gff3 file: D:\LinuxShare\Ciliates\Genomes\Annotations\ptetraurelia_mac_51_annotation_v2.0.gene.gff3
# Number of scaffolds: 539
# Reading sam file: D:\LinuxShare\Projects\Lyna\CharSeqPipe\EV_E_50MilReads\hisat2\WT_E_L1_R1R2.trim.Ass50Million.DNA20RNA20.dna.bridgePE.fastq.sort.F260.sam
# Number of scaffolds (in header): 0
# Total number of lines in sam file (excluding header): 7370312
# Mapped reads, so calculating seqs per feature and feature type
# Counting reads for all feature and Count reads per feature type (ex: exon, gene, CDS, etc.)
# ...
