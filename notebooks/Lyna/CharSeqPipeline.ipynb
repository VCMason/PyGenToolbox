# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipeline
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2020-02-26 17:13:30.868658

# %%
# char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/TestMyPipe/500_LK_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/TestMyPipe/500_LK_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac'
rnalen=15
dnalen=15
REsequence='GATC'
windowsize=300
contactcutoff=2
MQ=10
sn='Paramecium tetraurelia'


CharSeqPipeline.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, rnalen, dnalen, REsequence, windowsize, contactcutoff, MQ, sn)
# Out:
# Start trimming of:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/500_LK_L1_R1.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/500_LK_L1_R2.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp  Created
# Directory  /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp  already exists
# fastp -i /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/500_LK_L1_R1.fastq.gz -I /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/500_LK_L1_R2.fastq.gz -o /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R1.trim.fastq.gz -O /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R2.trim.fastq.gz
# b''
# Finished trimming, files output to:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R1.trim.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R2.trim.fastq.gz
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R1.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R1.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R1.trim.fastq
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R2.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R2.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R2.trim.fastq
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastqc
# Directory  /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastqc  Created
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R1.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastqc
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastqc
# Directory  /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastqc  already exists
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R2.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastqc
#
# Starting PEAR:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R1.trim.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R2.trim.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear  Created
# pear -f /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R1.trim.fastq.gz -r /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/fastp/500_LK_L1_R2.trim.fastq.gz -o  /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trim
# Finished PEAR, output at:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trim
#
# Start merging files
# Finished merging files:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.fastq
#
# Start packing files:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.fastq
# gzip -f -k /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.fastq
# Finished packing:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/char_bridge_trackall.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.DNA15RNA15. --minRNA 15 --minDNA 15
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.DNA15RNA15.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.DNA15RNA15.dna.bridgePE.fastq.gz
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.DNA15RNA15.rna.bridgePE.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.DNA15RNA15.rna.bridgePE.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.DNA15RNA15.rna.bridgePE.fastq
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.DNA15RNA15.dna.bridgePE.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.DNA15RNA15.dna.bridgePE.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.DNA15RNA15.dna.bridgePE.fastq
#
# converting fastq to fasta
# Converted fastq to fasta:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.DNA15RNA15.rna.bridgePE.fastq
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.DNA15RNA15.rna.bridgePE.fa
#
# Start calculations of percent free-floating human RNA contamination
# Expected percent of human-spiked-in of total RNA is 1 percent
# Start BLASTn on file:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.DNA15RNA15.rna.bridgePE.fa
# To Database:
# /media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa
#
# Directory  /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/blastn  Created
# Finished BLASTn, output results to:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/blastn/best_bit_score_per_query.blastn.RNA.tsv
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/blastn/human.rna.freefloating.tsv
#
# Measured percent of free-floating human RNA results: 11.764706
# Expected percent of free-floating RNA from Paramecium tetraurelia "contaminating" results: 1176.470588
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.DNA15RNA15.rna.bridgePE.fastq
# Directory  /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/hisat2  Created
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/pear/500_LK_L1_R1R2.trimAssUnFUnR.DNA15RNA15.dna.bridgePE.fastq
# Directory  /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/hisat2  already exists
# Finished with Hisat2
#
# Starting samtools
# Finished with Samtools
#
# Starting samtools
# Finished with Samtools
#
# Finished
# Finished2
# Finished3
# Start: counting number of restriction sites for each genomic window.
# Genome:
# /media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51.fa
# Window size: 300
# Finished counting restriction sites per window
#
# start restriction enzyme nut frequency normalization per window of size 300
# Finished normalized RNA-DNA contact support by restriction counts per window, output at:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/hisat2/RNA.DNA.Contacts.pt.wthickness.NormDPNII.tsv
#
# Finished normalized RNA-DNA contact support by restriction counts per window, rounded, output at:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/hisat2/RNA.DNA.Contacts.pt.wthickness.NormDPNIIrounded.tsv
#
# Finished normalized RNA-DNA contact support by restriction counts per window, log2 of normalized support, output at:
# /media/sf_LinuxShare/Projects/Lyna/TestMyPipe/hisat2/RNA.DNA.Contacts.pt.wthickness.NormDPNIILog2.tsv
#
# ##########
#     Fin
# ##########
