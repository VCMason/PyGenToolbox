# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineFour
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2022-03-14 12:58:15.807990

# %%
## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'    # '/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_sRNA20to30bps/pear/WT_L_L1_R1R2.trim.AssUnFUnR.fastq.gz'
altreadfile1 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
for i in range(246):
    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
    altreadfile1.append(splitfile)
    
#altreadfile2='/path/to/altreads2.fastq'
altreadfile2 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
for i in range(246):
    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
    altreadfile2.append(splitfile)
    

steps=['rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''  # leave blank, it skips a function that doesn't work
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 2000
rnabuffer = 15

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Starting to count rna and dna read positions and contacts
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.dna.sort.bam
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineFour
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-03-12 07:56:17.839196

# %%
## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.25bp.fa.gz'
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['blast rna']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''  # leave blank, it skips a function that doesn't work
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 2000
rnabuffer = 15

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.25bp.fa.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.25bp.fa.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.25bp.fa
#
# Start BLASTn on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.25bp.fa
# To Database:
# /media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs
#
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/blastn  already exists
# Pipe step 1.1
# ...

# %%
## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.short.fa.gz'
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['blast rna']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''  # leave blank, it skips a function that doesn't work
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 2000
rnabuffer = 15

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.short.fa.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.short.fa.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.short.fa
#
# Start BLASTn on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.short.fa
# To Database:
# /media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs
#
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/blastn  already exists
# Pipe step 1.1
# ...

# %%
## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.fa.gz'
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['blast rna']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''  # leave blank, it skips a function that doesn't work
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 2000
rnabuffer = 15

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.fa.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.fa.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.fa
#
# Start BLASTn on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.RNAs.ContactsNearIES.dnabuffer2000.rnabuffer15.fa
# To Database:
# /media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs
#
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/blastn  already exists
# Pipe step 1.1
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineFour
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-03-14 19:53:27.365646

# %%
### testing that RNAs are excluded if they are gapped over features of interest
## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
#    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['contacts in features', 'get sequences', 'blast rna']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''  # leave blank, it skips a function that doesn't work
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 2000
rnabuffer = 15
rnamatch=15
maxgapoverlap=0.75

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, rnamatch, maxgapoverlap, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Features kept: internal_eliminated_sequence
# Number of scaffolds: 511
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109']
# Count: 0 | Current contact: pt0 1 47 - 9S47M pt22 171171 171242 - 49M3I23M 3 A00574:219:HLYFTDRXX:1:2166:28646:2503:2:ATGTT,A00574:219:HLYFTDRXX:1:2166:28420:2581:2:ATGTT,A00574:219:HLYFTDRXX:1:2166:27525:17691:2:ATGTT
# Count: 1000000 | Current contact: pt10 254676 254814 + 85M30N24M1S pt17 468688 468841 + 87M30N37M 2 A00574:219:HLYFTDRXX:1:2136:2410:3818:1:AACAT,A00574:219:HLYFTDRXX:1:2136:2564:3959:1:AACAT
# Count: 2000000 | Current contact: pt22 221915 222051 - 137M pt37 277940 277996 + 57M 2 A00574:219:HLYFTDRXX:1:2176:9977:10066:1:AGCAT,A00574:219:HLYFTDRXX:1:2176:9950:10300:1:AGCAT
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineFour
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-03-15 18:55:21.167291

# %%
### testing that RNAs are excluded if they are gapped over features of interest
## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.insidefeatures.dnabuff2000.rnabuff15.match15.gap0.75.txt'
#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
#    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['get sequences']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''  # leave blank, it skips a function that doesn't work
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 2000
rnabuffer = 15
rnamatch=15
maxgapoverlap=0.75

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, rnamatch, maxgapoverlap, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# ['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split100.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split101.DNA20RNA20RNAmax300.rna.fastq.gz']
# 246
# Total Number of RNAs (after pear, before alignment): 21474325
# Total strength of all contacts in all features: 414
# Number of unique rna sequences from contacts in features: 414
# Number of unique short rna sequences (<=30bps) from contacts in features: 3
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineFour
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2022-03-15 22:03:56.191213

# %%
### MDS Matching contacts, RNA sequence maps to MDS ###

## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.txt'  # used when heatmap is first step
#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'  # used when contact in features is first step
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
#    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['heatmap', 'contacts in features', 'get sequences']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.MDS.gff3'
features=['mds']


zoomscaffname = ''  # leave blank, it skips a function that doesn't work
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 0  # no buffer needed for MDS features
rnabuffer = 0  # no buffer needed for MDS features
rnamatch=20  
maxgapoverlap=0.25  # exclude RNA with large gaps over MDS regions. Only keep contacts whose RNA have <= 25% of MDS length covered by gap.

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, rnamatch, maxgapoverlap, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Counting lengths of all scaffolds
# Summing lengths of all scaffolds
# Converting coordinates for each scaffold to continuous genome coordinates
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv
# [0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048]
# []
# [0.905, 0.905, 0.905, 0.905, 0.905, 0.905, 0.952, 1.0, 1.0, 1.0]
# scaffold51_0
# Maximum coordinate length: 40469, Minimum coordinate length: 0, Window size: 20000
# 3
# (3, 3)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.20000.log.pdf
# Maximum coordinate length: 40469, Minimum coordinate length: 0, Window size: 20000
# 3
# (3, 3)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.20000.log.UniqueContacts.pdf
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineFour
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-03-16 12:30:50.452330

# %%
### MDS Matching contacts, RNA sequence maps to MDS ###

## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.txt'  # used when heatmap is first step
altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'  # used when contact in features is first step
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
#    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['contacts in features', 'get sequences']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.MDS.gff3'
features=['mds']


zoomscaffname = ''  # leave blank, it skips a function that doesn't work
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 0  # no buffer needed for MDS features
rnabuffer = 0  # no buffer needed for MDS features
rnamatch=20  
maxgapoverlap=0.25  # exclude RNA with large gaps over MDS regions. Only keep contacts whose RNA have <= 25% of MDS length covered by gap.

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, rnamatch, maxgapoverlap, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.MDS.gff3
# Features kept: mds
# Number of scaffolds: 697
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109']
# Count: 0 | Current contact: pt0 1 47 - 9S47M pt22 171171 171242 - 49M3I23M 3 A00574:219:HLYFTDRXX:1:2166:28646:2503:2:ATGTT,A00574:219:HLYFTDRXX:1:2166:28420:2581:2:ATGTT,A00574:219:HLYFTDRXX:1:2166:27525:17691:2:ATGTT
# Count: 1000000 | Current contact: pt10 254676 254814 + 85M30N24M1S pt17 468688 468841 + 87M30N37M 2 A00574:219:HLYFTDRXX:1:2136:2410:3818:1:AACAT,A00574:219:HLYFTDRXX:1:2136:2564:3959:1:AACAT
# Count: 2000000 | Current contact: pt22 221915 222051 - 137M pt37 277940 277996 + 57M 2 A00574:219:HLYFTDRXX:1:2176:9977:10066:1:AGCAT,A00574:219:HLYFTDRXX:1:2176:9950:10300:1:AGCAT
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineFour
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-03-19 10:32:13.183800

# %%
### MDS Matching contacts, RNA sequence maps to MDS ###

## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.txt'  # used when heatmap is first step
#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'  # used when contact in features is first step
altreadfile1 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
for i in range(246):
    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
    altreadfile1.append(splitfile)
    
#altreadfile2='/path/to/altreads2.fastq'
altreadfile2 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
for i in range(246):
    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
    altreadfile2.append(splitfile)
    

steps=['rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
hisat2_args='-p 2 --max-intronlen 6000'  # --no-softclip
# if mapping to Mac+IES
# hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gene.gff3'
features=['gene']


zoomscaffname = ''  # leave blank, it skips a function that doesn't work
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 0  # no buffer needed for MDS features
rnabuffer = 0  # no buffer needed for MDS features
rnamatch=20  
maxgapoverlap=0.25  # exclude RNA with large gaps over MDS regions. Only keep contacts whose RNA have <= 25% of MDS length covered by gap.

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, rnamatch, maxgapoverlap, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Starting to count rna and dna read positions and contacts
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.dna.sort.bam
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineFour
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-03-22 23:37:33.073580

# %%
### MDS Matching contacts, RNA sequence maps to MDS ###

## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.txt'  # used when heatmap is first step
altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'  # used when contact in features is first step
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['contacts in features', 'get sequences']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
hisat2_args='-p 2 --max-intronlen 6000'  # --no-softclip
# if mapping to Mac+IES
# hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gene.gff3'
features=['gene']


zoomscaffname = ''  # leave blank, it skips a function that doesn't work
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 0  # no buffer needed for MDS features
rnabuffer = 0  # no buffer needed for MDS features
rnamatch=20  
maxgapoverlap=0.25  # exclude RNA with large gaps over MDS regions. Only keep contacts whose RNA have <= 25% of MDS length covered by gap.

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, rnamatch, maxgapoverlap, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gene.gff3
# Features kept: gene
# Number of scaffolds: 539
# ['1', '10', '100', '101', '102', '103', '104', '105', '106', '107']
# Count: 0 | Current contact: pt0 1 47 - 9S47M pt22 164072 164143 - 49M3I23M 3 A00574:219:HLYFTDRXX:1:2166:28646:2503:2:ATGTT,A00574:219:HLYFTDRXX:1:2166:28420:2581:2:ATGTT,A00574:219:HLYFTDRXX:1:2166:27525:17691:2:ATGTT
# Count: 1000000 | Current contact: pt10 244376 244484 - 109M pt1 228603 228697 + 4S95M 1 A00574:219:HLYFTDRXX:1:2119:24921:24330:1:AACAT
# Count: 2000000 | Current contact: pt22 219080 219130 - 51M pt131 252171 252352 + 182M 1 A00574:219:HLYFTDRXX:1:2127:32759:19805:1:TACAT
# Count: 3000000 | Current contact: pt36 460500 460609 + 110M pt1 355249 355347 + 99M 2 A00574:219:HLYFTDRXX:1:2162:28700:12399:1:TACAT,A00574:219:HLYFTDRXX:1:2162:29179:12508:1:TACAT
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineFour
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-03-24 15:28:10.019822

# %%
### MDS Matching contacts, RNA sequence maps to MDS ###

## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.txt'  # used when heatmap is first step
altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'  # used when contact in features is first step
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['trans rna']  # , 'get sequences'
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
hisat2_args='-p 2 --max-intronlen 6000'  # --no-softclip
# if mapping to Mac+IES
# hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gene.gff3'
features=['gene']

zoomscaffname = ''  # leave blank, it skips a function that doesn't work
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 0  # no buffer needed for MDS features
rnabuffer = 0  # no buffer needed for MDS features
rnamatch=20  
maxgapoverlap=0.25  # exclude RNA with large gaps over MDS regions. Only keep contacts whose RNA have <= 25% of MDS length covered by gap.
rnalocation=[387, 20, 5985]  # lnc1 [387, 20, 5985] # lnc15 [357, 21, 979]

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, rnamatch, maxgapoverlap, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features, rnalocation)
# Out:
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gene.gff3
# Features kept: gene
# Number of scaffolds: 539
# ['1', '10', '100', '101', '102', '103', '104', '105', '106', '107']
# Count: 0 | Current contact: pt0 1 47 - 9S47M pt22 164072 164143 - 49M3I23M 3 A00574:219:HLYFTDRXX:1:2166:28646:2503:2:ATGTT,A00574:219:HLYFTDRXX:1:2166:28420:2581:2:ATGTT,A00574:219:HLYFTDRXX:1:2166:27525:17691:2:ATGTT
# Count: 1000000 | Current contact: pt10 244376 244484 - 109M pt1 228603 228697 + 4S95M 1 A00574:219:HLYFTDRXX:1:2119:24921:24330:1:AACAT
# Count: 2000000 | Current contact: pt22 219080 219130 - 51M pt131 252171 252352 + 182M 1 A00574:219:HLYFTDRXX:1:2127:32759:19805:1:TACAT
# Count: 3000000 | Current contact: pt36 460500 460609 + 110M pt1 355249 355347 + 99M 2 A00574:219:HLYFTDRXX:1:2162:28700:12399:1:TACAT,A00574:219:HLYFTDRXX:1:2162:29179:12508:1:TACAT
# ...

# %%
### MDS Matching contacts, RNA sequence maps to MDS ###

## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.txt'  # used when heatmap is first step
altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'  # used when contact in features is first step
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['trans rna']  # , 'get sequences'
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
hisat2_args='-p 2 --max-intronlen 6000'  # --no-softclip
# if mapping to Mac+IES
# hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gene.gff3'
features=['gene']

zoomscaffname = ''  # leave blank, it skips a function that doesn't work
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 0  # no buffer needed for MDS features
rnabuffer = 0  # no buffer needed for MDS features
rnamatch=20  
maxgapoverlap=0.25  # exclude RNA with large gaps over MDS regions. Only keep contacts whose RNA have <= 25% of MDS length covered by gap.
rnalocation=[357, 21, 979]  # lnc1 [387, 20, 5985] # lnc15 [357, 21, 979]

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, rnamatch, maxgapoverlap, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features, rnalocation)
# Out:
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gene.gff3
# Features kept: gene
# Number of scaffolds: 539
# ['1', '10', '100', '101', '102', '103', '104', '105', '106', '107']
# Count: 0 | Current contact: pt0 1 47 - 9S47M pt22 164072 164143 - 49M3I23M 3 A00574:219:HLYFTDRXX:1:2166:28646:2503:2:ATGTT,A00574:219:HLYFTDRXX:1:2166:28420:2581:2:ATGTT,A00574:219:HLYFTDRXX:1:2166:27525:17691:2:ATGTT
# Count: 1000000 | Current contact: pt10 244376 244484 - 109M pt1 228603 228697 + 4S95M 1 A00574:219:HLYFTDRXX:1:2119:24921:24330:1:AACAT
# Count: 2000000 | Current contact: pt22 219080 219130 - 51M pt131 252171 252352 + 182M 1 A00574:219:HLYFTDRXX:1:2127:32759:19805:1:TACAT
# Count: 3000000 | Current contact: pt36 460500 460609 + 110M pt1 355249 355347 + 99M 2 A00574:219:HLYFTDRXX:1:2162:28700:12399:1:TACAT,A00574:219:HLYFTDRXX:1:2162:29179:12508:1:TACAT
# ...

# %%
### MDS Matching contacts, RNA sequence maps to MDS ###

## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac_with_IES_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.txt'  # used when heatmap is first step
altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'  # used when contact in features is first step
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['trans rna']  # , 'get sequences'
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
hisat2_args='-p 2 --max-intronlen 6000'  # --no-softclip
# if mapping to Mac+IES
# hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']

zoomscaffname = ''  # leave blank, it skips a function that doesn't work
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 1000  # no buffer needed for MDS features
rnabuffer = 0  # no buffer needed for MDS features
rnamatch=20  
maxgapoverlap=0.25  # exclude RNA with large gaps over MDS regions. Only keep contacts whose RNA have <= 25% of MDS length covered by gap.
rnalocation = [387, 20, 6208]  # add 223 to 5985 (=) because 223 extra bases are added to the Mac+IES genome as IESs inside of the lnc1 coordinates for the Mac 
                               # no IESs inside the lnc15 coordinates, so don't need to change them

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, rnamatch, maxgapoverlap, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features, rnalocation)
# Out:
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Features kept: internal_eliminated_sequence
# Number of scaffolds: 511
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109']
# Count: 0 | Current contact: pt0 1 47 - 9S47M pt22 171171 171242 - 49M3I23M 3 A00574:219:HLYFTDRXX:1:2166:28646:2503:2:ATGTT,A00574:219:HLYFTDRXX:1:2166:28420:2581:2:ATGTT,A00574:219:HLYFTDRXX:1:2166:27525:17691:2:ATGTT
# Count: 1000000 | Current contact: pt10 254676 254814 + 85M30N24M1S pt17 468688 468841 + 87M30N37M 2 A00574:219:HLYFTDRXX:1:2136:2410:3818:1:AACAT,A00574:219:HLYFTDRXX:1:2136:2564:3959:1:AACAT
# Count: 2000000 | Current contact: pt22 221915 222051 - 137M pt37 277940 277996 + 57M 2 A00574:219:HLYFTDRXX:1:2176:9977:10066:1:AGCAT,A00574:219:HLYFTDRXX:1:2176:9950:10300:1:AGCAT
# ...

# %%
### MDS Matching contacts, RNA sequence maps to MDS ###

## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.txt'  # used when heatmap is first step
altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'  # used when contact in features is first step
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['trans rna']  # , 'get sequences'
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap', 'contacts in features', 'get sequences', 'blast rna']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
hisat2_args='-p 2 --max-intronlen 6000'  # --no-softclip
# if mapping to Mac+IES
# hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']

zoomscaffname = ''  # leave blank, it skips a function that doesn't work
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 1000  # no buffer needed for MDS features
rnabuffer = 0  # no buffer needed for MDS features
rnamatch=20  
maxgapoverlap=0.25  # exclude RNA with large gaps over MDS regions. Only keep contacts whose RNA have <= 25% of MDS length covered by gap.
rnalocation=[357, 21, 979]  # lnc1 [387, 20, 5985] # lnc15 [357, 21, 979]

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, rnamatch, maxgapoverlap, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features, rnalocation)
# Out:
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Features kept: internal_eliminated_sequence
# Number of scaffolds: 511
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109']
# Count: 0 | Current contact: pt0 1 47 - 9S47M pt22 171171 171242 - 49M3I23M 3 A00574:219:HLYFTDRXX:1:2166:28646:2503:2:ATGTT,A00574:219:HLYFTDRXX:1:2166:28420:2581:2:ATGTT,A00574:219:HLYFTDRXX:1:2166:27525:17691:2:ATGTT
# Count: 1000000 | Current contact: pt10 254676 254814 + 85M30N24M1S pt17 468688 468841 + 87M30N37M 2 A00574:219:HLYFTDRXX:1:2136:2410:3818:1:AACAT,A00574:219:HLYFTDRXX:1:2136:2564:3959:1:AACAT
# Count: 2000000 | Current contact: pt22 221915 222051 - 137M pt37 277940 277996 + 57M 2 A00574:219:HLYFTDRXX:1:2176:9977:10066:1:AGCAT,A00574:219:HLYFTDRXX:1:2176:9950:10300:1:AGCAT
# ...
