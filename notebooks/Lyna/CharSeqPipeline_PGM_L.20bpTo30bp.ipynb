# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipeline

# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2021-01-22 19:44:39.211403

# %%
#merge failed so i did the stuff below
#(base) victor@victorVBox:/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear$ cp PGM_L_S2_L002_R1_R1R2.trim.assembled.fastq PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.fastq 
#(base) victor@victorVBox:/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear$ cat PGM_L_S2_L002_R1_R1R2.trim.unassembled.forward.fastq >> PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.fastq 
#(base) victor@victorVBox:/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear$ cat PGM_L_S2_L002_R1_R1R2.trim.unassembled.reverse.fastq >> PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.fastq 
# skipping BLAST

# char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
# forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_50MilReads/WT_E_L1_R1.fastq.gz'
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/PGM_L_S2_L002_R1_001.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/PGM_L_S2_L002_R2_001.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES'
# altreadfile='/path/to/altreads.fastq'
# altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.fastq.gz'
altreadfile1=['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split2.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split3.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split4.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split5.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split6.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split7.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split8.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split9.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split10.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split11.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split12.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split13.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split14.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split15.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split16.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split17.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split18.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split19.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split20.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split21.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split22.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split23.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split24.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split25.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split26.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split27.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split28.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split29.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split30.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split31.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split32.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split33.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split34.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split35.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split36.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split37.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split38.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split39.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split40.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split41.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split42.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split43.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split44.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split45.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split46.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split47.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split48.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split49.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split50.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split51.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split52.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split53.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split54.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split55.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split56.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split57.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split58.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split59.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split60.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split61.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split62.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split63.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split64.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split65.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split66.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split67.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split68.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split69.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split70.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split71.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split72.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split73.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split74.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split75.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split76.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split77.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split78.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split79.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split80.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split81.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split82.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split83.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split84.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split85.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split86.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split87.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split88.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split89.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split90.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split91.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split92.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split93.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split94.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split95.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split96.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split97.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split98.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split99.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split100.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split101.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split102.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split103.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split104.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split105.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split106.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split107.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split108.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split109.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split110.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split111.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split112.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split113.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split114.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split115.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split116.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split117.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split118.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split119.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split120.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split121.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split122.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split123.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split124.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split125.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split126.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split127.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split128.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split129.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split130.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split131.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split132.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split133.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split134.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split135.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split136.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split137.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split138.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split139.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split140.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split141.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split142.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split143.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split144.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split145.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split146.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split147.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split148.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split149.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split150.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split151.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split152.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split153.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split154.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split155.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split156.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split157.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split158.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split159.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split160.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split161.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split162.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split163.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split164.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split165.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split166.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split167.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split168.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split169.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split170.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split171.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split172.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split173.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split174.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split175.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split176.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split177.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split178.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split179.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split180.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split181.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split182.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split183.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split184.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split185.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split186.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split187.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split188.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split189.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split190.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split191.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split192.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split193.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split194.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split195.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split196.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split197.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split198.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split199.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split200.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split201.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split202.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split203.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split204.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split205.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split206.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split207.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split208.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split209.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split210.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split211.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split212.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split213.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split214.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split215.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split216.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split217.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split218.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split219.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split220.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split221.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split222.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split223.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split224.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split225.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split226.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split227.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split228.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split229.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split230.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split231.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split232.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split233.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split234.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split235.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split236.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split237.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split238.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split239.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split240.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split241.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split242.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split243.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split244.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split245.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split246.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split247.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split248.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split249.fastq.gz', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split250.fastq.gz']

altreadfile2='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/NotUsed.fastq.gz'

# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap']
steps=['charbridge', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap']  # 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 
rnalen=20
dnalen=20
rnamaxlen=30
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=10
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2 --no-softclip'
# if mapping to Mac+IES
hisat2_args='-p 2 --no-softclip --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies.fa'
PCRDupRemoval=True

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = 'scaffold51_2'
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]


CharSeqPipeline.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/char_bridge_trackall.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax30. --minRNA 20 --minDNA 20 --maxRNA 30
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax30.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax30.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipeline

# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2021-03-02 16:20:23.749785

# %%
#merge failed so i did the stuff below
#(base) victor@victorVBox:/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear$ cp PGM_L_S2_L002_R1_R1R2.trim.assembled.fastq PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.fastq 
#(base) victor@victorVBox:/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear$ cat PGM_L_S2_L002_R1_R1R2.trim.unassembled.forward.fastq >> PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.fastq 
#(base) victor@victorVBox:/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear$ cat PGM_L_S2_L002_R1_R1R2.trim.unassembled.reverse.fastq >> PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.fastq 
# skipping BLAST

# char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
# forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_50MilReads/WT_E_L1_R1.fastq.gz'
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/PGM_L_S2_L002_R1_001.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/PGM_L_S2_L002_R2_001.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES'
# altreadfile='/path/to/altreads.fastq'
# altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.fastq.gz'
altreadfile1=['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split55.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split56.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split57.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split58.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split59.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split60.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split61.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split62.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split63.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split64.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split65.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split66.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split67.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split68.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split69.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split70.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split71.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split72.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split73.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split74.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split75.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split76.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split77.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split78.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split79.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split80.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split81.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split82.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split83.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split84.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split85.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split86.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split87.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split88.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split89.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split90.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split91.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split92.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split93.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split94.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split95.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split96.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split97.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split98.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split99.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split100.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split101.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split102.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split103.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split104.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split105.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split106.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split107.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split108.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split109.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split110.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split111.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split112.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split113.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split114.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split115.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split116.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split117.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split118.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split119.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split120.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split121.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split122.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split123.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split124.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split125.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split126.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split127.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.
DNA20RNA20RNAmax30.rna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split237.DNA20RNA20RNAmax30.rna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split238.DNA20RNA20RNAmax30.rna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split239.DNA20RNA20RNAmax30.rna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split240.DNA20RNA20RNAmax30.rna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split241.DNA20RNA20RNAmax30.rna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split242.DNA20RNA20RNAmax30.rna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split243.DNA20RNA20RNAmax30.rna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split244.DNA20RNA20RNAmax30.rna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split245.DNA20RNA20RNAmax30.rna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split246.DNA20RNA20RNAmax30.rna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split247.DNA20RNA20RNAmax30.rna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split248.DNA20RNA20RNAmax30.rna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split249.DNA20RNA20RNAmax30.rna.bridgePE.sort.bam', \
              '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split250.DNA20RNA20RNAmax30.rna.bridgePE.sort.bam']

# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap']
steps=['rnadnacontacts', 'normalize', 'heatmap']  # 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 
rnalen=20
dnalen=20
rnamaxlen=30
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=10
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2 --no-softclip'
# if mapping to Mac+IES
hisat2_args='-p 2 --no-softclip --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies.fa'
PCRDupRemoval=True

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = 'scaffold51_2'
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]


CharSeqPipeline.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Starting to count rna and dna read positions and contacts
# Remove PCR duplicates because PCRDupRemoval is set to True
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L_sRNA20to30bps/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax30.dna.bridgePE.sort.bam
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipeline

# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2020-12-03 13:30:08.061613

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox.SeqsPerFeatureAndFeatureTypeAndGOTerms import main
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2020-06-09 21:01:16.657276

# %%
#GOfile only has GO terms for genes and therefore we must limit the Gff3file to only genes

Gff3file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gff3'
samfilelist = ['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_50MilReads/hisat2/WT_E_L1_R1R2.trim.Ass50Million.DNA20RNA20.dna.bridgePE.sort.sam']
GOfile = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/Ptetraurelia51_GOTerms.tsv'

# count number of reads per feature
# count number of reads per feature type (exon, mRNA, 5' UTR, etc.) and sort so counts are decreasing

main(Gff3file, samfilelist, GOfile)
# Out:
# Reading Gff3 file: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gene.gff3
# Number of scaffolds: 539
# Reading sam file: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_50MilReads/hisat2/WT_E_L1_R1R2.trim.Ass50Million.DNA20RNA20.dna.bridgePE.sort.sam
# Number of scaffolds: 697
# Total number of lines in sam file (excluding header): 7600243
# Number of GO term entries (lines in file) = 86461
# Counting reads for all feature and Count reads per feature type (ex: exon, gene, CDS, etc.)
# scaffold51_1
# scaffold51_10
# scaffold51_100
# scaffold51_101
# scaffold51_102
# scaffold51_103
# scaffold51_104
# scaffold51_105
# scaffold51_106
# scaffold51_107
# scaffold51_108
# scaffold51_109
# scaffold51_11
# scaffold51_110
# scaffold51_111
# scaffold51_112
# scaffold51_113
# scaffold51_114
# scaffold51_115
# scaffold51_116
# scaffold51_117
# scaffold51_118
# scaffold51_119
# scaffold51_12
# scaffold51_120
# scaffold51_121
# scaffold51_122
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox.SeqsPerFeatureAndFeatureTypeAndGOTerms import main
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2020-06-10 10:24:21.124165

# %%
#GOfile only has GO terms for genes and therefore we must limit the Gff3file to only genes

Gff3file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gff3'
samfilelist = ['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_50MilReads/hisat2/WT_E_L1_R1R2.trim.Ass50Million.DNA20RNA20.rna.bridgePE.sort.sam']
GOfile = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/Ptetraurelia51_GOTerms.tsv'

# count number of reads per feature
# count number of reads per feature type (exon, mRNA, 5' UTR, etc.) and sort so counts are decreasing

main(Gff3file, samfilelist, GOfile)
# Out:
# Reading Gff3 file: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gff3
# Number of scaffolds: 539
# Reading sam file: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_50MilReads/hisat2/WT_E_L1_R1R2.trim.Ass50Million.DNA20RNA20.rna.bridgePE.sort.sam
# Number of scaffolds: 697
# Total number of lines in sam file (excluding header): 7206389
# Number of GO term entries (lines in file) = 86461
# Counting reads for all feature and Count reads per feature type (ex: exon, gene, CDS, etc.)
# scaffold51_1
# scaffold51_10
# scaffold51_100
# scaffold51_101
# scaffold51_102
# scaffold51_103
# scaffold51_104
# scaffold51_105
# scaffold51_106
# scaffold51_107
# scaffold51_108
# scaffold51_109
# scaffold51_11
# scaffold51_110
# scaffold51_111
# scaffold51_112
# scaffold51_113
# scaffold51_114
# scaffold51_115
# scaffold51_116
# scaffold51_117
# scaffold51_118
# scaffold51_119
# scaffold51_12
# scaffold51_120
# scaffold51_121
# scaffold51_122
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox.SeqsPerFeatureAndFeatureTypeFixed import main
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2020-06-23 11:08:54.019758

# %%
#GOfile only has GO terms for genes and therefore we must limit the Gff3file to only genes

#Gff3file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gff3'
Gff3file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
### this sam file is mapped to mac+IES genome, connections normalized at every 400bps
samfilelist = ['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_50MilReads/hisat2/WT_E_L1_R1R2.trim.Ass50Million.DNA20RNA20.rna.bridgePE.fastq.sort.sam']

# count number of reads per feature
# count number of reads per feature type (exon, mRNA, 5' UTR, etc.) and sort so counts are decreasing

main(Gff3file, samfilelist)
# Out:
# Reading Gff3 file: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Number of scaffolds: 511
# Reading sam file: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_50MilReads/hisat2/WT_E_L1_R1R2.trim.Ass50Million.DNA20RNA20.rna.bridgePE.fastq.sort.sam
# Number of scaffolds (in header): 697
# Total number of lines in sam file (excluding header): 7141929
# Mapped reads, so calculating seqs per feature and feature type
# Counting reads for all feature and Count reads per feature type (ex: exon, gene, CDS, etc.)
# Writing out file: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_50MilReads/hisat2/WT_E_L1_R1R2.trim.Ass50Million.DNA20RNA20.rna.bridgePE.fastq.sort.allfeatures.fixed.tsv
# Writing out file: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_50MilReads/hisat2/WT_E_L1_R1R2.trim.Ass50Million.DNA20RNA20.rna.bridgePE.fastq.sort.allfeatures.sorted.fixed.tsv
# ...
