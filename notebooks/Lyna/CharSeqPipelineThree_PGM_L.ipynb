# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineThree
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2022-02-16 22:51:04.844537

# %%
# char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/PGM_L_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/PGM_L_L1_R1.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_sRNA20to30bps/pear/WT_L_L1_R1R2.trim.AssUnFUnR.fastq.gz'
altreadfile1 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/'
for i in range(251):
    splitfile = os.path.join(path, f'PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split{i}.fastq.gz')
    altreadfile1.append(splitfile)
    
#altreadfile2='/path/to/altreads2.fastq'
altreadfile2 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/'
for i in range(251):
    splitfile = os.path.join(path, f'PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split{i}.fastq.gz')
    altreadfile2.append(splitfile)
   
steps=['charbridge', 'hisat2', 'samtools', 'rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  #--no-softclip 
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip 
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]

dnabuffer = 2000
rnabuffer = 15

CharSeqPipelineThree.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split2.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split2.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split3.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split3.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split4.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split4.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split5.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split5.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split6.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split6.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split7.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split7.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split8.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split8.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split9.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split9.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split10.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split10.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split11.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split11.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split12.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split12.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split13.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split13.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split14.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split14.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split15.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split15.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split16.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split16.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split17.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split17.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split18.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split18.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split19.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split19.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split20.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split20.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split21.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split21.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split22.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split22.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split23.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split23.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split24.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split24.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split25.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split25.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split26.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split26.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split27.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split27.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split28.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split28.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split29.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split29.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split30.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split30.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split31.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split31.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split32.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split32.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split33.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split33.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split34.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split34.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split35.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split35.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split36.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split36.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split37.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split37.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split38.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split38.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split39.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split39.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split40.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split40.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split41.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split41.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split42.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split42.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split43.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split43.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split44.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split44.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split45.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split45.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split46.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split46.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split47.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split47.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split48.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split48.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split49.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split49.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split50.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split50.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split51.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split51.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split52.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split52.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split53.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split53.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split54.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split54.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split55.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split55.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split55.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split55.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split55.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split56.fastq.gz
# ...
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split226.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split226.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split226.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split226.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split226.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split227.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split227.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split227.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split227.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split227.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split228.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split228.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split228.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split228.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split228.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split229.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split229.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split229.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split229.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split229.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split230.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split230.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split230.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split230.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split230.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split231.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split231.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split231.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split231.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split231.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split232.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split232.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split232.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split232.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split232.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split233.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split233.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split233.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split233.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split233.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split234.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split234.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split234.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split234.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split234.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split235.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split235.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split235.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split235.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split235.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split236.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split236.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split236.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split236.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split236.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split237.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split237.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split237.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split237.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split237.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split238.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split238.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split238.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split238.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split238.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split239.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split239.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split239.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split239.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split239.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split240.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split240.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split240.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split240.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split240.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split241.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split241.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split241.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split241.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split241.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split242.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split242.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split242.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split242.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split242.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split243.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split243.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split243.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split243.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split243.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split244.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split244.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split244.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineThree
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2022-02-18 16:26:12.222298

# %%
# char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/PGM_L_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/PGM_L_L1_R1.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_sRNA20to30bps/pear/WT_L_L1_R1R2.trim.AssUnFUnR.fastq.gz'
altreadfile1 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/'
for i in range(244, 251):
    splitfile = os.path.join(path, f'PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split{i}.fastq.gz')
    altreadfile1.append(splitfile)
    
#altreadfile2='/path/to/altreads2.fastq'
altreadfile2 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/'
for i in range(244, 251):
    splitfile = os.path.join(path, f'PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split{i}.fastq.gz')
    altreadfile2.append(splitfile)
   
steps=['charbridge']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  #--no-softclip 
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --max-intronlen 6000 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip 
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]

dnabuffer = 2000
rnabuffer = 15

CharSeqPipelineThree.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split244.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split244.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split244.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split244.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split244.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split245.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split245.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split245.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split245.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split245.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split246.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split246.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split246.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split246.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split246.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split247.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split247.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split247.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split247.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split247.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split248.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split248.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split248.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split248.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split248.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split249.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split249.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split249.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split249.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split249.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split250.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split250.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split250.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split250.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split250.DNA20RNA20RNAmax300.dna.fastq.gz
#
# ##########
#     Fin
# ##########

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineThree
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-02-18 17:04:31.457657

# %%
# char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/PGM_L_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/PGM_L_L1_R1.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_sRNA20to30bps/pear/WT_L_L1_R1R2.trim.AssUnFUnR.fastq.gz'
altreadfile1 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/'
for i in range(251):
    splitfile = os.path.join(path, f'PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.fastq.gz')
    altreadfile1.append(splitfile)
    
#altreadfile2='/path/to/altreads2.fastq'
altreadfile2 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/'
for i in range(251):
    splitfile = os.path.join(path, f'PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.fastq.gz')
    altreadfile2.append(splitfile)
   
steps=['hisat2', 'samtools', 'rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  #--no-softclip 
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --max-intronlen 6000 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip 
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]

dnabuffer = 2000
rnabuffer = 15

CharSeqPipelineThree.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  Created
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split55.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split55.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split56.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split56.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split57.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split57.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split58.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split58.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split59.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split59.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split60.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split60.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split61.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split61.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split62.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split62.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split63.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split63.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split64.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split64.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split65.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split65.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split66.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split66.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split67.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split67.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split68.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split68.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split69.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split69.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split70.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split70.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split71.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split71.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split72.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split72.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split73.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split73.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split74.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split74.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split75.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split75.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split76.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split76.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split77.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split77.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split78.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split78.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split79.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split79.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split80.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split80.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split81.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split81.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split82.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split82.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split83.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split83.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split84.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split84.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split85.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split85.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split86.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split86.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split87.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split87.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split88.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# ...
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split188.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split189.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split190.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split191.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split192.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split193.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split194.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split195.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split196.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split197.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split198.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split199.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split200.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split201.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split202.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split203.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split204.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split205.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split206.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split207.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split208.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split209.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split210.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split211.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split212.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split213.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split214.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split215.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split216.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split217.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split218.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split219.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split220.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split221.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split222.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split223.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split224.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split225.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split226.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split227.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split228.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split229.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split230.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split231.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split232.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split233.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split234.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split235.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split236.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split237.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split238.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split239.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split240.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split241.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split242.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split243.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split244.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split245.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split246.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split247.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split248.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split249.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split250.DNA20RNA20RNAmax300.dna.sort.bam
# Finished recording 3' rna and 5'dna read positions and raw RNA-DNA contacts
# Starting Summarize RNA DNA contacts, and sequence names
# Number of raw contacts = 37208569
# Number of unique contacts = 16499484
# Average contact strength = 2.2551353121103666
# writing out unique, but not sorted contacts
# sorting contacts
# contacts sorted
# Finished summarizing RNA DNA contacts
# Counting lengths of all scaffolds
# Summing lengths of all scaffolds
# Converting coordinates for each scaffold to continuous genome coordinates
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv
# [0.008, 0.008, 0.008, 0.008, 0.008, 0.008, 0.008, 0.008, 0.008, 0.008]
# []
# [0.576, 0.576, 0.593, 0.627, 0.636, 0.636, 0.678, 0.814, 0.856, 1.0]
# scaffold51_0
# Maximum coordinate length: 40469, Minimum coordinate length: 0, Window size: 20000
# 3
# (3, 3)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.20000.log.pdf
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.20000.pdf
# Maximum coordinate length: 40469, Minimum coordinate length: 0, Window size: 5000
# 9
# (9, 9)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.5000.log.pdf
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.5000.pdf
# ['scaffold51_0', 'scaffold51_1']
# Maximum coordinate length: 3000000, Minimum coordinate length: 0, Window size: 5000
# 600
# (600, 600)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.3000000.5000.log.pdf
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.3000000.5000.pdf
# Maximum coordinate length: 75698530, Minimum coordinate length: 0, Window size: 50000
# 1514
# (1514, 1514)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.75698530.50000.log.pdf
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.75698530.50000.pdf
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Number of scaffolds: 511
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109']
# Count: 0 | Current contact: pt0 1 36 - pt81 371367 371435 - 4 A00574:280:HVV7FDRXX:2:2134:19416:33990:1:AAAGG,A00574:280:HVV7FDRXX:2:2147:23439:3286:1:AAAGG,A00574:280:HVV7FDRXX:2:2216:25319:35822:1:AAAGG,A00574:280:HVV7FDRXX:2:2216:25500:36041:1:AAAGG
# Count: 1000000 | Current contact: pt5 488387 488472 - pt76 251085 251166 + 1 A00574:280:HVV7FDRXX:2:2156:16089:27445:1:AACGT
# Count: 2000000 | Current contact: pt11 482425 482539 - pt11 443562 443727 - 4 A00574:280:HVV7FDRXX:2:2205:27453:37012:1:AATTC,A00574:280:HVV7FDRXX:2:2206:27163:1376:1:AATTC,A00574:280:HVV7FDRXX:2:2206:27127:1407:1:AATTC,A00574:280:HVV7FDRXX:2:2206:27181:1407:1:AATTC
# Count: 3000000 | Current contact: pt18 259887 259975 + pt13 300498 300607 + 1 A00574:280:HVV7FDRXX:2:2266:5954:2221:1:AATTG
# ['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split100.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split101.DNA20RNA20RNAmax300.rna.fastq.gz']
# 251
# Total Number of RNAs (after pear, before alignment): 71100751
# Total Number of Contacts in features: 29098
# Number of unique rna sequences from contacts in features: 29098
# Number of unique short rna sequences (<=30bps) from contacts in features: 820
# Number of unique short rna sequences (==25bps) from contacts in features: 96
# ##########
#     Fin
# ##########

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineThree
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2022-02-20 12:09:21.627500

# %%
# char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/PGM_L_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/PGM_L_L1_R1.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_sRNA20to30bps/pear/WT_L_L1_R1R2.trim.AssUnFUnR.fastq.gz'
altreadfile1 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/'
for i in range(251):
    splitfile = os.path.join(path, f'PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.fastq.gz')
    altreadfile1.append(splitfile)
    
#altreadfile2='/path/to/altreads2.fastq'
altreadfile2 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/'
for i in range(251):
    splitfile = os.path.join(path, f'PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.fastq.gz')
    altreadfile2.append(splitfile)
   
steps=['hisat2', 'samtools', 'rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
hisat2_args='-p 2 --max-intronlen 6000'  #--no-softclip 
# if mapping to Mac+IES
# hisat2_args='-p 2 --pen-noncansplice 0 --max-intronlen 6000 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip 
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gene.gff3'
features=['gene']


zoomscaffname = ''
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]

dnabuffer = 2000
rnabuffer = 15

CharSeqPipelineThree.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split55.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split55.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split56.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split56.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split57.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split57.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split58.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split58.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split59.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split59.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split60.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split60.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split61.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split61.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split62.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split62.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split63.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split63.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split64.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split64.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split65.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split65.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split66.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split66.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split67.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split67.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split68.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split68.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split69.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split69.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split70.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split70.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split71.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split71.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split72.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split72.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split73.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split73.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split74.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split74.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split75.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split75.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split76.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split76.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split77.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split77.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split78.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split78.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split79.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split79.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split80.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split80.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split81.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split81.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split82.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split82.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split83.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split83.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split84.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split84.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split85.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split85.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split86.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split86.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split87.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split87.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split88.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# ...
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split185.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split186.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split187.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split188.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split189.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split190.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split191.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split192.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split193.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split194.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split195.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split196.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split197.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split198.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split199.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split200.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split201.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split202.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split203.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split204.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split205.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split206.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split207.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split208.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split209.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split210.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split211.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split212.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split213.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split214.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split215.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split216.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split217.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split218.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split219.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split220.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split221.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split222.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split223.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split224.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split225.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split226.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split227.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split228.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split229.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split230.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split231.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split232.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split233.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split234.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split235.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split236.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split237.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split238.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split239.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split240.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split241.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split242.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split243.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split244.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split245.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split246.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split247.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split248.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split249.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split250.DNA20RNA20RNAmax300.dna.sort.bam
# Finished recording 3' rna and 5'dna read positions and raw RNA-DNA contacts
# Starting Summarize RNA DNA contacts, and sequence names
# Number of raw contacts = 36738382
# Number of unique contacts = 16281943
# Average contact strength = 2.2563880735855664
# writing out unique, but not sorted contacts
# sorting contacts
# contacts sorted
# Finished summarizing RNA DNA contacts
# Counting lengths of all scaffolds
# Summing lengths of all scaffolds
# Converting coordinates for each scaffold to continuous genome coordinates
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv
# [0.008, 0.008, 0.008, 0.008, 0.008, 0.008, 0.008, 0.008, 0.008, 0.008]
# []
# [0.576, 0.576, 0.593, 0.627, 0.636, 0.636, 0.678, 0.814, 0.864, 1.0]
# scaffold51_0
# Maximum coordinate length: 40469, Minimum coordinate length: 0, Window size: 20000
# 3
# (3, 3)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.20000.log.pdf
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.20000.pdf
# Maximum coordinate length: 40469, Minimum coordinate length: 0, Window size: 5000
# 9
# (9, 9)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.5000.log.pdf
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.5000.pdf
# ['scaffold51_0', 'scaffold51_1']
# Maximum coordinate length: 3000000, Minimum coordinate length: 0, Window size: 5000
# 600
# (600, 600)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.3000000.5000.log.pdf
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.3000000.5000.pdf
# Maximum coordinate length: 72143410, Minimum coordinate length: 0, Window size: 50000
# 1443
# (1443, 1443)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.72143410.50000.log.pdf
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.72143410.50000.pdf
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gene.gff3
# Number of scaffolds: 539
# ['1', '10', '100', '101', '102', '103', '104', '105', '106', '107']
# Count: 0 | Current contact: pt0 1 36 - pt81 357574 357642 - 4 A00574:280:HVV7FDRXX:2:2134:19416:33990:1:AAAGG,A00574:280:HVV7FDRXX:2:2147:23439:3286:1:AAAGG,A00574:280:HVV7FDRXX:2:2216:25319:35822:1:AAAGG,A00574:280:HVV7FDRXX:2:2216:25500:36041:1:AAAGG
# Count: 1000000 | Current contact: pt5 520760 520810 - pt54 28493 28528 - 1 A00574:280:HVV7FDRXX:2:2153:15637:10316:1:AATGT
# Count: 2000000 | Current contact: pt11 562771 562828 + pt59 339673 339797 - 3 A00574:280:HVV7FDRXX:2:2126:16721:3082:1:AAGGG,A00574:280:HVV7FDRXX:2:2126:16740:3051:1:AAGGG,A00574:280:HVV7FDRXX:2:2126:16776:3051:1:AAGGG
# Count: 15000000 | Current contact: pt162 40297 40458 + pt162 179899 179993 + 2 A00574:280:HVV7FDRXX:2:2226:31512:3427:1:CTAAA,A00574:280:HVV7FDRXX:2:2226:31512:3458:1:CTAAA
# Count: 16000000 | Current contact: pt274 9972 10015 + pt112 178875 178970 + 3 A00574:280:HVV7FDRXX:2:2176:31421:28917:1:AAGTC,A00574:280:HVV7FDRXX:2:2176:29975:31140:1:AAGTC,A00574:280:HVV7FDRXX:2:2177:28655:10755:1:AAGTC
# ['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split100.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split101.DNA20RNA20RNAmax300.rna.fastq.gz']
# 251

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineThree
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2022-02-20 21:31:17.427651

# %%
# char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/PGM_L_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/PGM_L_L1_R1.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.insidefeatures.dnabuffer2000.rnabuffer15.txt'
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/'
#for i in range(251):
#    splitfile = os.path.join(path, f'PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.fastq.gz')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/'
#for i in range(251):
#    splitfile = os.path.join(path, f'PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.fastq.gz')
#    altreadfile2.append(splitfile)
   
steps=['get sequences']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
hisat2_args='-p 2 --max-intronlen 6000'  #--no-softclip 
# if mapping to Mac+IES
# hisat2_args='-p 2 --pen-noncansplice 0 --max-intronlen 6000 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip 
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/ptetraurelia_mac_51_annotation_v2.0.gene.gff3'
features=['gene']


zoomscaffname = ''
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]

dnabuffer = 2000
rnabuffer = 15

CharSeqPipelineThree.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# ['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split100.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/PGM_L/pear/PGM_L_S2_L002_R1_R1R2.trim.AssUnFUnR.split101.DNA20RNA20RNAmax300.rna.fastq.gz']
# 251
# Total Number of RNAs (after pear, before alignment): 71100751
# Total Number of Contacts in features: 723651
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-a125cb49b9e1> in <module>
#      53 rnabuffer = 15
#      54
# ---> 55 CharSeqPipelineThree.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineThree.py in main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, sn, alignargs, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#    1498         peardirectory = os.path.join(path, 'pear')
#    1499         rnafastqfiles = list_of_files_from_dir(peardirectory, extension='.rna.fastq.gz')
# -> 1500         rnaseqfile, scnrnaseqfile = retrieve_rna_sequences_from_contacts_inside_features(seqnames, rnafastqfiles, dnabuffer=dnabuffer, rnabuffer=rnabuffer)
#    1501
#    1502     if 'blast rna' in steps:
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineThree.py in retrieve_rna_sequences_from_contacts_inside_features(seqnames, rnafastqfiles, dnabuffer, rnabuffer)
#      64     # print(f'difference: {len(diff)}, {list(diff)[:5]}')
#      65
# ---> 66     outrnas = [b'>%s\n%s' % (bytes(k, encoding='utf8'), drna[bytes(k, encoding='utf8')]) for k in seqnames]
#      67     print(f'Number of unique rna sequences from contacts in features: {len(outrnas)}')
#      68     outshortrnas = [b'>%s\n%s' % (bytes(k, encoding='utf8'), drna[bytes(k, encoding='utf8')]) for k in seqnames if len(drna[bytes(k, encoding='utf8')]) <= 30]
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineThree.py in <listcomp>(.0)
#      64     # print(f'difference: {len(diff)}, {list(diff)[:5]}')
#      65
# ---> 66     outrnas = [b'>%s\n%s' % (bytes(k, encoding='utf8'), drna[bytes(k, encoding='utf8')]) for k in seqnames]
#      67     print(f'Number of unique rna sequences from contacts in features: {len(outrnas)}')
#      68     outshortrnas = [b'>%s\n%s' % (bytes(k, encoding='utf8'), drna[bytes(k, encoding='utf8')]) for k in seqnames if len(drna[bytes(k, encoding='utf8')]) <= 30]
#
# KeyError: b'A00574:219:HLYFTDRXX:1:2101:1063:5149:1:TAACA'
