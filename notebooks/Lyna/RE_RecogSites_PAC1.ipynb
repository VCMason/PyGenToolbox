# %%
# %load_ext autoreload
# %autoreload 2
import datetime
print(datetime.datetime.now())

# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pygentoolbox.CountRESites import main_CountRESites

# %%
main_CountRESites()
# Out:
# Enter full path to file:  D:\\LinuxShare\\Ciliates\\Genomes\\Seqs\\ptetraurelia_mac_51.fa
# Enter restriction enzyme pattern, ex. GATC:  TTAATTAA
# D:\\LinuxShare\\Ciliates\\Genomes\\Seqs\\ptetraurelia_mac_51.fa
# Number of sequences: 697
# Number of RE sites matching TTAATTAA: 26582
# Expected number of RE recognition sites for sequence of length 72102941 and pattern of length 8 = 1100
# Cuttting efficiency = 0.900000
# [1581, 456, 1103, 1594, 143, 1624, 1466, 2588, 1619, 5546, 2746, 2285, 6368, 3953, 930, 427, 6037, 4520, 721, 17840, 3931, 7009, 4389, 1745, 3150, 1380, 5473, 5406, 2294, 11345, 142, 487, 1623, 838, 1541, 588, 682, 3165, 748, 481, 824, 24, 581, 962, 556, 8888, 5197, 960, 1331, 2105, 1719, 4920, 2830, 4765, 38, 1512, 871, 2301, 8229, 2091, 914, 659, 617, 4128, 4885, 1610, 10796, 11745, 1261, 2343, 3313, 4405, 1652, 803, 3814, 5007, 6478, 2152, 46, 1690, 4197, 8, 797, 4249, 9070, 914, 747, 499, 416, 374, 6769, 3237, 460, 3959, 3666, 1827, 3499, 851, 2940, 4024]
# Mean of fragment size: 2929.871859
# Mean of mean fragment size > 1000: 4051.372911
# Mean of mean fragment size > 2000: 5119.461051

# %%
main_CountRESites()
# Out:
# Enter full path to file:  D:\\LinuxShare\\Ciliates\\Genomes\\Seqs\\ptetraurelia_mac_51_with_ies.fa
# Enter restriction enzyme pattern, ex. GATC:  TTAATTAA
# D:\\LinuxShare\\Ciliates\\Genomes\\Seqs\\ptetraurelia_mac_51_with_ies.fa
# Number of sequences: 697
# Number of RE sites matching TTAATTAA: 29205
# Expected number of RE recognition sites for sequence of length 75658061 and pattern of length 8 = 1154
# Cuttting efficiency = 0.900000
# [1581, 456, 1598, 1594, 143, 1386, 238, 1466, 2588, 1619, 5546, 2746, 8653, 4018, 930, 427, 6484, 4668, 909, 7598, 10579, 4036, 938, 6170, 4503, 1745, 4530, 461, 1025, 4153, 5435, 2294, 8038, 3628, 142, 487, 1623, 2379, 588, 682, 2756, 464, 1229, 824, 24, 581, 1036, 556, 9026, 176, 4060, 1336, 1052, 1331, 2283, 477, 1330, 5385, 8149, 38, 1512, 871, 2550, 8682, 2091, 961, 743, 707, 4296, 5165, 1228, 382, 1095, 99, 3287, 7739, 11954, 1331, 1224, 4822, 4549, 191, 1487, 803, 4101, 5033, 6667, 2181, 46, 196, 1930, 4300, 8, 797, 1725, 2616, 9490, 944, 747, 499]
# Mean of fragment size: 2798.402168
# Mean of mean fragment size > 1000: 3905.627357
# Mean of mean fragment size > 2000: 4963.090640

# %%
main_CountRESites()
# Out:
# Enter full path to file:  D:\\LinuxShare\\Ciliates\\Genomes\\Seqs\\ptetraurelia_mic2.fa
# Enter restriction enzyme pattern, ex. GATC:  TTAATTAA
# D:\\LinuxShare\\Ciliates\\Genomes\\Seqs\\ptetraurelia_mic2.fa
# Number of sequences: 26186
# Number of RE sites matching TTAATTAA: 38037
# Expected number of RE recognition sites for sequence of length 98489268 and pattern of length 8 = 1502
# Cuttting efficiency = 0.900000
# [385, 420, 8143, 606, 234, 176, 1462, 3789, 4598, 1187, 421, 710, 1282, 7994, 572, 4586, 333, 1145, 1914, 6547, 2631, 3287, 4431, 8587, 394, 35, 3418, 1061, 2816, 3350, 1941, 2396, 546, 159, 3665, 92, 1294, 5312, 26, 107, 351, 24, 214, 4419, 291, 135, 2372, 399, 301, 2960, 2516, 782, 6521, 6177, 6968, 8006, 3925, 1759, 1824, 1137, 910, 1620, 2379, 2639, 2208, 44, 446, 3023, 112, 534, 67, 1859, 5139, 1374, 13855, 386, 2372, 4295, 3878, 7044, 1396, 3031, 5661, 1264, 2637, 51, 25, 438, 1313, 3835, 1756, 3751, 70, 3065, 1167, 2064, 4069, 1819, 1580, 1135]
# Mean of fragment size: 2288.837427
# Mean of mean fragment size > 1000: 3534.262566
# Mean of mean fragment size > 2000: 4616.555080
