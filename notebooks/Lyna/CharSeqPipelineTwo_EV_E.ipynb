# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineTwo
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2022-02-05 15:01:27.777606

# %%
## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_sRNA20to30bps/pear/WT_L_L1_R1R2.trim.AssUnFUnR.fastq.gz'
altreadfile1 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/'
for i in range(246):
    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.fastq.gz')
    altreadfile1.append(splitfile)
    
#altreadfile2='/path/to/altreads2.fastq'
altreadfile2 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_mtDNA/pear/'
for i in range(246):
    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.fastq.gz')
    altreadfile2.append(splitfile)
    

steps=['charbridge', 'hisat2', 'samtools', 'rnadnacontacts', 'heatmap']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = 'scaffold51_2'
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]


CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split0.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split0.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split1.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split1.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split2.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split2.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split3.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split3.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split4.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split4.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split5.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split5.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split6.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split6.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split7.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split7.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split8.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split8.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split9.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split9.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split10.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split10.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split11.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split11.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split12.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split12.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split13.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split13.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split14.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split14.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split15.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split15.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split16.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split16.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split17.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split17.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split18.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split18.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split19.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split19.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split20.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split20.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split21.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split21.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split22.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split22.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split23.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split23.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split24.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split24.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split25.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split25.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split26.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split26.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split27.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split27.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split28.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split28.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split29.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split29.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split30.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split30.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split31.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split31.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split32.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split32.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split33.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split33.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split34.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split34.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split35.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split35.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split36.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split36.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split37.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split37.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split38.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split38.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split39.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split39.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split40.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split40.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split41.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split41.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split42.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split42.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split43.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split43.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split44.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split44.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split45.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split45.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split46.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split46.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split47.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split47.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split48.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split48.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split49.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split49.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split50.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split50.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split51.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split51.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split52.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split52.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split53.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split53.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split54.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split54.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split55.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split55.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split55.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split55.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split55.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split56.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split56.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split56.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split56.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split56.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split57.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split57.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split57.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split57.DNA20RNA20RNAmax300.rna.bridgePE.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split57.DNA20RNA20RNAmax300.dna.bridgePE.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split58.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split58.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split58.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# ...
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split146.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split147.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split148.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split149.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split150.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split151.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split152.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split153.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split154.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split155.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split156.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split157.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split158.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split159.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split160.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split161.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split162.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split163.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split164.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split165.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split166.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split167.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split168.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split169.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split170.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split171.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split172.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split173.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split174.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split175.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split176.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split177.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split178.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split179.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split180.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split181.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split182.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split183.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split184.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split185.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split186.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split187.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split188.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split189.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split190.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split191.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split192.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split193.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split194.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split195.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split196.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split197.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split198.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split199.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split200.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split201.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split202.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split203.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split204.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split205.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split206.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split207.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split208.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split209.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split210.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split211.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split212.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split213.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split214.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split215.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split216.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split217.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split218.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split219.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split220.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split221.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split222.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split223.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split224.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split225.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split226.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split227.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split228.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split229.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split230.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split231.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split232.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split233.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split234.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split235.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split236.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split237.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split238.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split239.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split240.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split241.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split242.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split243.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split244.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split245.DNA20RNA20RNAmax300.dna.bridgePE.sort.bam
# Finished recording 3' rna and 5'dna read positions and raw RNA-DNA contacts
# Starting Summarize RNA DNA contacts, and sequence names
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-55794fb85efd> in <module>
#      52
#      53
# ---> 54 CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineTwo.py in main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, alignargs, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#    1307         print('Finished recording 3\' rna and 5\'dna read positions and raw RNA-DNA contacts')
#    1308
# -> 1309         contactfilenames, contactfile, contactfilecircos = summarize_raw_rna_dna_contacts_and_names(rawcontactfilenames)
#    1310
#    1311         # contactfile = summarize_raw_rna_dna_contacts(rawcontactfile, rawcontactfilenames, sn, PCRDupRemoval)
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineTwo.py in summarize_raw_rna_dna_contacts_and_names(rawcontactfilenames)
#     524     # record all sequence names for all unique contacts
#     525     d = {}  # d is dict, key is unique rna_dna contact position 'rnascaff rnastart ...', value is list of all read names
# --> 526     with open(rawcontactfilenames, 'r') as FILE:
#     527         # line structure rnascaffold, rnastartpos, rnaendpos, dnascaff, dnastart, dnaend, NNNbarcode (from bridge)
#     528         for l in FILE:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.wNames.pt.raw.txt'

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineTwo
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-02-07 08:25:41.550883

# %%
## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_sRNA20to30bps/pear/WT_L_L1_R1R2.trim.AssUnFUnR.fastq.gz'
altreadfile1 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/'
for i in range(246):
    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.fastq.gz')
    altreadfile1.append(splitfile)
    
#altreadfile2='/path/to/altreads2.fastq'
altreadfile2 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/'
for i in range(246):
    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.fastq.gz')
    altreadfile2.append(splitfile)
    

steps=['hisat2', 'samtools', 'rnadnacontacts', 'heatmap']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = 'scaffold51_2'
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]


CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split55.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split55.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split56.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split56.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split57.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split57.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split58.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split58.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split59.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split59.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split60.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split60.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split61.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split61.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split62.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split62.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split63.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split63.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split64.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split64.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split65.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split65.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split66.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split66.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split67.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split67.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split68.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split68.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split69.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split69.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split70.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split70.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split71.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split71.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split72.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split72.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split73.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split73.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split74.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split74.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split75.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split75.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split76.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split76.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split77.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split77.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split78.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split78.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split79.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split79.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split80.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split80.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split81.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split81.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split82.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split82.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split83.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split83.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split84.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split84.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split85.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split85.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split86.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split86.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split87.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split87.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split88.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split88.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split89.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split89.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split90.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split90.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split91.DNA20RNA20RNAmax300.rna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split91.DNA20RNA20RNAmax300.dna.fastq.gz
# Directory  /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2  already exists
# Finished with Hisat2
#
# Starting Hisat2: aligning
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split92.DNA20RNA20RNAmax300.rna.fastq.gz
# ...
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split139.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split140.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split141.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split142.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split143.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split144.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split145.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split146.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split147.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split148.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split149.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split150.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split151.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split152.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split153.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split154.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split155.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split156.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split157.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split158.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split159.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split160.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split161.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split162.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split163.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split164.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split165.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split166.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split167.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split168.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split169.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split170.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split171.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split172.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split173.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split174.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split175.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split176.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split177.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split178.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split179.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split180.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split181.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split182.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split183.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split184.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split185.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split186.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split187.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split188.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split189.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split190.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split191.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split192.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split193.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split194.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split195.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split196.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split197.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split198.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split199.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split200.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split201.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split202.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split203.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split204.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split205.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split206.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split207.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split208.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split209.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split210.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split211.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split212.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split213.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split214.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split215.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split216.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split217.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split218.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split219.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split220.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split221.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split222.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split223.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split224.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split225.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split226.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split227.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split228.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split229.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split230.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split231.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split232.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split233.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split234.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split235.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split236.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split237.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split238.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split239.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split240.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split241.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split242.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split243.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split244.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split245.DNA20RNA20RNAmax300.dna.sort.bam
# Finished recording 3' rna and 5'dna read positions and raw RNA-DNA contacts
# Starting Summarize RNA DNA contacts, and sequence names
# Finished summarizing RNA DNA contacts
# Counting lengths of all scaffolds
# Summing lengths of all scaffolds
# Converting coordinates for each scaffold to continuous genome coordinates
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-61bc25d68e2f> in <module>
#      52
#      53
# ---> 54 CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineTwo.py in main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, alignargs, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#    1345
#    1346         gencoordcontactsfile, x, y, intensity = convert_scaff_coords_to_continuous_genome_coords(contactfile,
# -> 1347                                                                                                    dscaffgenomecoords)
#    1348         print(gencoordcontactsfile)
#    1349         # sort x and y coordinates by intensity values (large are last)
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineTwo.py in convert_scaff_coords_to_continuous_genome_coords(contactfile, dgcoords)
#     309         for line in FILE:
#     310             l = line.strip().split()
# --> 311             support = int(math.ceil(float(l[-1])))  # round up to nearest integer # math.ceil returns float()
#     312             rnascaff = 'scaffold51_%d' % int(l[0][2:])
#     313             dnascaff = 'scaffold51_%d' % int(l[3][2:])
#
# ValueError: could not convert string to float: 'thickness=1.0p'

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineTwo
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-02-07 14:41:02.995672

# %%
## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_sRNA20to30bps/pear/WT_L_L1_R1R2.trim.AssUnFUnR.fastq.gz'
altreadfile1 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
for i in range(246):
    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
    altreadfile1.append(splitfile)
    
#altreadfile2='/path/to/altreads2.fastq'
altreadfile2 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
for i in range(246):
    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
    altreadfile2.append(splitfile)
    

steps=['rnadnacontacts', 'heatmap']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'heatmap']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = 'scaffold51_2'
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]


CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Starting to count rna and dna read positions and contacts
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split55.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split56.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split57.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split58.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split59.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split60.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split61.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split62.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split63.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split64.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split65.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split66.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split67.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split68.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split69.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split70.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split71.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split72.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split73.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split74.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split75.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split76.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split77.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split78.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split79.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split80.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split81.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split82.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split83.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split84.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split85.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split86.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split87.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split88.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split89.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split90.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split91.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split92.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split93.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split94.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split95.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split96.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split97.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split98.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split99.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split100.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split101.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split102.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split103.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split104.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split105.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split106.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split107.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split108.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split109.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split110.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split111.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split112.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split113.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split114.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split115.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split116.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split117.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split118.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split119.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split120.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split121.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split122.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split123.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split124.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split125.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split126.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split127.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split128.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split129.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split130.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split131.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split132.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split133.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split134.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split135.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split136.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split137.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split138.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split139.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split140.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split141.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split142.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split143.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split144.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split145.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split146.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split147.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split148.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split149.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split150.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split151.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split152.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split153.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split154.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split155.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split156.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split157.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split158.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split159.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split160.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split161.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split162.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split163.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split164.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split165.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split166.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split167.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split168.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split169.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split170.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split171.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split172.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split173.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split174.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split175.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split176.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split177.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split178.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split179.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split180.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split181.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split182.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split183.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split184.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split185.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split186.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split187.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split188.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split189.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split190.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split191.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split192.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split193.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split194.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split195.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split196.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split197.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split198.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split199.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split200.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split201.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split202.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split203.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split204.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split205.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split206.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split207.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split208.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split209.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split210.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split211.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split212.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split213.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split214.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split215.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split216.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split217.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split218.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split219.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split220.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split221.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split222.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split223.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split224.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split225.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split226.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split227.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split228.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split229.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split230.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split231.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split232.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split233.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split234.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split235.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split236.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split237.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split238.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split239.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split240.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split241.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split242.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split243.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split244.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/WT_E_L1_R1R2.trim.AssUnFUnR.split245.DNA20RNA20RNAmax300.dna.sort.bam
# Finished recording 3' rna and 5'dna read positions and raw RNA-DNA contacts
# Starting Summarize RNA DNA contacts, and sequence names
# Finished summarizing RNA DNA contacts
# Counting lengths of all scaffolds
# Summing lengths of all scaffolds
# Converting coordinates for each scaffold to continuous genome coordinates
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.txt.gencoords.tsv
# [0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032]
# []
# [0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.613, 0.613, 0.613, 0.613, 0.613, 0.613, 0.613, 0.613, 0.645, 0.645, 0.645, 0.645, 0.645, 0.645, 0.677, 0.677, 0.677, 0.677, 0.774, 0.774, 0.774, 0.806, 0.806, 0.806, 0.806, 0.871, 0.968, 0.968]
# Reading Gff3 file: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Number of features: 44928
# Zooming in on scaffold51_2 from 219999 to 239999
# Trimming features to scaffold: scaffold51_2_with_IES, start: 220000, end: 240000
# first five features: ['IESPGM.PTET51.1.2.218155', 'IESPGM.PTET51.1.2.218617', 'IESPGM.PTET51.1.2.219164', 'IESPGM.PTET51.1.2.222020', 'IESPGM.PTET51.1.2.223760']
# number of features: 13
# Maximum coordinate length: 1302443, Minimum coordinate length: 1282443, Window size: 50
# 400
# (400, 400)
# Plotting heatmap with horizontal bar plot
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-c56aa2707986> in <module>
#      52
#      53
# ---> 54 CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineTwo.py in main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, alignargs, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#    1394                                                                                       mincoordinate=mincoord)
#    1395                 seaborn_heatmap_with_barh(matrixlog, '%s.%s.%d.%d.%d.barh.log.pdf' % (gencoordcontactsfile, zoomscaffname, scaffmin,
# -> 1396                                                                             scaffmax, zoomwinsize), trimfeatures, ys, starts, lengths)
#    1397                 # seaborn_heatmap_with_barh(matrix, '%s.%s.%d.%d.%d.barh.pdf' % (gencoordcontactsfile, zoomscaffname, scaffmin,
#    1398                 #                                                         scaffmax, zoomwinsize), trimfeatures, ys, starts, lengths)
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineTwo.py in seaborn_heatmap_with_barh(matrix, outpath, names, ys, starts, lengths)
#     178     # axes[1].set(ylabel=None)
#     179     axes[0].get_yaxis().set_visible(False)
# --> 180     axes[0].barh(y=ys, width=lengths, left=starts)
#     181     ends = [starts[i] + lengths[i] for i in range(len(starts))]
#     182     for s, e in zip(starts, ends):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2595         kwargs.setdefault('orientation', 'horizontal')
#    2596         patches = self.bar(x=left, height=height, width=width, bottom=y,
# -> 2597                            align=align, **kwargs)
#    2598         return patches
#    2599
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2373         x, height, width, y, linewidth = np.broadcast_arrays(
#    2374             # Make args iterable too.
# -> 2375             np.atleast_1d(x), height, width, y, linewidth)
#    2376
#    2377         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     262     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     263
# --> 264     shape = _broadcast_shape(*args)
#     265
#     266     if all(array.shape == shape for array in args):
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     189     # use the old-iterator because np.nditer does not handle size 0 arrays
#     190     # consistently
# --> 191     b = np.broadcast(*args[:32])
#     192     # unfortunately, it cannot handle 32 or more arguments directly
#     193     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineTwo
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-02-08 15:31:36.144559

# %%
## char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.wNames.pt.raw.txt'
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['summarizecontacts', 'heatmap']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'summarizecontacts', normalize', 'heatmap']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = 'scaffold51_2'
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]


CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Starting Summarize RNA DNA contacts, and sequence names
# writing out unique, but not sorted contacts
# sorting contacts
# contacts sorted
# Finished summarizing RNA DNA contacts
# Counting lengths of all scaffolds
# Summing lengths of all scaffolds
# Converting coordinates for each scaffold to continuous genome coordinates
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.txt.gencoords.tsv
# [0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032, 0.032]
# []
# [0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.516, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.548, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.581, 0.613, 0.613, 0.613, 0.613, 0.613, 0.613, 0.613, 0.613, 0.645, 0.645, 0.645, 0.645, 0.645, 0.645, 0.677, 0.677, 0.677, 0.677, 0.774, 0.774, 0.774, 0.806, 0.806, 0.806, 0.806, 0.871, 0.968, 0.968]
# Reading Gff3 file: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Number of features: 44928
# Zooming in on scaffold51_2 from 219999 to 239999
# Trimming features to scaffold: scaffold51_2_with_IES, start: 220000, end: 240000
# first five features: ['IESPGM.PTET51.1.2.218155', 'IESPGM.PTET51.1.2.218617', 'IESPGM.PTET51.1.2.219164', 'IESPGM.PTET51.1.2.222020', 'IESPGM.PTET51.1.2.223760']
# number of features: 13
# Maximum coordinate length: 1302443, Minimum coordinate length: 1282443, Window size: 50
# 400
# (400, 400)
# Plotting heatmap with horizontal bar plot
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-3dadbe539b35> in <module>
#      52
#      53
# ---> 54 CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineTwo.py in main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, alignargs, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#    1415                                                                                       mincoordinate=mincoord)
#    1416                 seaborn_heatmap_with_barh(matrixlog, '%s.%s.%d.%d.%d.barh.log.pdf' % (gencoordcontactsfile, zoomscaffname, scaffmin,
# -> 1417                                                                             scaffmax, zoomwinsize), trimfeatures, ys, starts, lengths)
#    1418                 # seaborn_heatmap_with_barh(matrix, '%s.%s.%d.%d.%d.barh.pdf' % (gencoordcontactsfile, zoomscaffname, scaffmin,
#    1419                 #                                                         scaffmax, zoomwinsize), trimfeatures, ys, starts, lengths)
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineTwo.py in seaborn_heatmap_with_barh(matrix, outpath, names, ys, starts, lengths)
#     178     # axes[1].set(ylabel=None)
#     179     axes[0].get_yaxis().set_visible(False)
# --> 180     axes[0].barh(y=ys, width=lengths, left=starts)
#     181     ends = [starts[i] + lengths[i] for i in range(len(starts))]
#     182     for s, e in zip(starts, ends):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2595         kwargs.setdefault('orientation', 'horizontal')
#    2596         patches = self.bar(x=left, height=height, width=width, bottom=y,
# -> 2597                            align=align, **kwargs)
#    2598         return patches
#    2599
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2373         x, height, width, y, linewidth = np.broadcast_arrays(
#    2374             # Make args iterable too.
# -> 2375             np.atleast_1d(x), height, width, y, linewidth)
#    2376
#    2377         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     262     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     263
# --> 264     shape = _broadcast_shape(*args)
#     265
#     266     if all(array.shape == shape for array in args):
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     189     # use the old-iterator because np.nditer does not handle size 0 arrays
#     190     # consistently
# --> 191     b = np.broadcast(*args[:32])
#     192     # unfortunately, it cannot handle 32 or more arguments directly
#     193     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineTwo
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-02-09 14:08:29.131846

# %%
#### char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.txt'
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['heatmap']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'summarizecontacts', 'heatmap']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''  # scaffold51_2  # leave blank and it will skip
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]


CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Counting lengths of all scaffolds
# Summing lengths of all scaffolds
# Converting coordinates for each scaffold to continuous genome coordinates
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv
# [0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033, 0.033]
# []
# [0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.533, 0.567, 0.567, 0.567, 0.567, 0.567, 0.567, 0.567, 0.567, 0.567, 0.567, 0.567, 0.567, 0.567, 0.567, 0.567, 0.567, 0.567, 0.567, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.633, 0.633, 0.633, 0.633, 0.633, 0.633, 0.633, 0.633, 0.667, 0.667, 0.667, 0.667, 0.667, 0.667, 0.7, 0.7, 0.7, 0.7, 0.8, 0.8, 0.8, 0.833, 0.833, 0.833, 0.833, 0.9, 1.0, 1.0]
# scaffold51_0
# Maximum coordinate length: 40469, Minimum coordinate length: 0, Window size: 20000
# 3
# (3, 3)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.20000.log.pdf
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.20000.pdf
# Maximum coordinate length: 40469, Minimum coordinate length: 0, Window size: 5000
# 9
# (9, 9)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.5000.log.pdf
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.5000.pdf
# ['scaffold51_0', 'scaffold51_1']
# Maximum coordinate length: 3000000, Minimum coordinate length: 0, Window size: 5000
# 600
# (600, 600)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.3000000.5000.log.pdf
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.3000000.5000.pdf
# Maximum coordinate length: 75698530, Minimum coordinate length: 0, Window size: 50000
# 1514
# (1514, 1514)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.75698530.50000.log.pdf
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.75698530.50000.pdf
# internal_eliminated_sequence
# Reading Gff3 file: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Number of features: 44928
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-af735c8ed9ff> in <module>
#      52
#      53
# ---> 54 CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineTwo.py in main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, alignargs, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#    1470             rnawindowend = [dgff3[k][4] for k in featureids]
#    1471             # rnafeaturecontactfile = limit_contacts_by_feature(dgff3, normalizedcontactsfile)
# -> 1472             rnafeaturecontactfile = limit_contacts_by_feature(dgff3, contactfile)
#    1473             gencoordcontactsfile2, x2, y2, intensity2 = convert_scaff_coords_to_continuous_genome_coords(rnafeaturecontactfile, dscaffgenomecoords)
#    1474             winsize = 100000
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineTwo.py in limit_contacts_by_feature(dgff3, contactfile)
#     109             for k, v in dgff3.items():
#     110                 # only keep connections where RNA map to features included in dgff3 (ex: keep only ncRNA or only mRNA)
# --> 111                 if (rnascaff == v[0]) and (rnastart >= int(v[3])) and (rnastart <= int(v[4])):
#     112                     # dcounts[k] = dcounts.setdefault(k, 0) + support
#     113                     outlines.append(line.strip())
#
# KeyboardInterrupt:

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineTwo
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-02-11 08:29:24.626105

# %%
#### char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.txt'
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['cumulative distribution']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'summarizecontacts', 'heatmap', 'cumulative distribution']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''  # scaffold51_2  # leave blank and it will skip
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]


CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Reading Gff3 file: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Number of features: 44928
# 0: pt0 1 2 pt14 347015 347016 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-c90618bb6eba> in <module>
#      52
#      53
# ---> 54 CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineTwo.py in main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, alignargs, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#    1468         # cumulative distribution plot
#    1469         dgff3, featureids = read_gff3(annot_file, features)
# -> 1470         rnafeaturecontactfile = limit_contacts_by_feature(dgff3, contactfile)
#    1471         minrpkm = 0
#    1472         dcountnorm, normcountfile = count_contacts_by_feature_norm_length(dgff3, rnafeaturecontactfile, minrpkm)
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineTwo.py in limit_contacts_by_feature(dgff3, contactfile)
#     111                 # only keep connections where RNA map to features included in dgff3 (ex: keep only ncRNA or only mRNA)
#     112                 #if (rnascaff == v[0]) and (rnastart >= int(v[3])) and (rnastart <= int(v[4])):
# --> 113                 if rnascaff == v[0]:
#     114                     gate = 1
#     115                     if (rnastart >= int(v[3])) and (rnastart <= int(v[4])):
#
# KeyboardInterrupt:

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineTwo
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-02-14 17:34:13.697870

# %%
#### char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['sequences in features']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'summarizecontacts', 'heatmap', 'sequences in features', 'cumulative distribution']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''  # scaffold51_2  # leave blank and it will skip
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]


CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Number of scaffolds: 511
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109']
# Count: 0 | Current contact: pt0 1 2 pt14 347015 347016 1 A00574:219:HLYFTDRXX:1:2141:26259:15060:1:AACAT
# Count: 1000000 | Current contact: pt10 305116 305117 pt57 413277 413278 1 A00574:219:HLYFTDRXX:1:2114:24858:25316:1:TACAT
# Count: 2000000 | Current contact: pt22 307791 307792 pt66 41199 41200 3 A00574:219:HLYFTDRXX:1:2118:17318:24251:2:AACAT,A00574:219:HLYFTDRXX:1:2118:17409:24283:2:AACAT,A00574:219:HLYFTDRXX:1:2118:18159:26115:2:AACAT
# Count: 3000000 | Current contact: pt37 78379 78380 pt177 13450 13451 1 A00574:219:HLYFTDRXX:1:2125:13901:28729:1:AACAT
# Count: 4000000 | Current contact: pt52 432319 432320 pt4 194812 194813 3 A00574:219:HLYFTDRXX:1:2238:21540:8234:1:TACAT,A00574:219:HLYFTDRXX:1:2238:21992:8422:1:TACAT,A00574:219:HLYFTDRXX:1:2238:21206:8437:1:TACAT
# Count: 5000000 | Current contact: pt70 28112 28113 pt41 232538 232539 1 A00574:219:HLYFTDRXX:1:2252:14877:11224:1:TTTAT
# Count: 6000000 | Current contact: pt90 313610 313611 pt7 426887 426888 1 A00574:219:HLYFTDRXX:1:2151:3242:26365:1:AACAT
# Count: 7000000 | Current contact: pt115 72513 72514 pt90 17696 17697 2 A00574:219:HLYFTDRXX:1:2116:24713:14011:1:AACAT,A00574:219:HLYFTDRXX:1:2116:24189:15953:1:AACAT
# Count: 8000000 | Current contact: pt143 202876 202877 pt143 202540 202541 3 A00574:219:HLYFTDRXX:1:2205:12319:3129:1:CTCAG,A00574:219:HLYFTDRXX:1:2205:12617:3490:1:CTCAG,A00574:219:HLYFTDRXX:1:2205:15266:6167:1:CTCAG
# Count: 9000000 | Current contact: pt181 104324 104325 pt149 209477 209478 1 A00574:219:HLYFTDRXX:1:2278:26124:31861:2:TGAAC
# ['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split100.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split101.DNA20RNA20RNAmax300.rna.fastq.gz']
# 246
# Total Number of RNAs (after pear, before alignment): 21474325
# Total Number of Contacts in features: 10885312
# Number of unique rna sequences from contacts in features: 10885312
# Number of unique short rna sequences (<=30bps) from contacts in features: 512411
# Number of unique short rna sequences (==25bps) from contacts in features: 45743
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-70d925a74e57> in <module>
#      52
#      53
# ---> 54 CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineTwo.py in main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, sn, alignargs, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
#    1655         peardirectory = os.path.join(path, 'pear')
#    1656         rnafastqfiles = list_of_files_from_dir(peardirectory, extension='.rna.fastq.gz')
# -> 1657         retrieve_rna_sequences_from_contacts_inside_features(seqnames, rnafastqfiles)
#    1658
#    1659     if 'cumulative distribution' in steps:
#
# ~/anaconda3/lib/python3.7/site-packages/pygentoolbox/CharSeqPipelineTwo.py in retrieve_rna_sequences_from_contacts_inside_features(seqnames, rnafastqfiles)
#      80         OUT.write(b'\n'.join(outshortrnas))
#      81     with gzip.open(outscnfile, 'w') as OUT:
# ---> 82         OUT.write(b'\n'.join(outscnfile))
#      83
#      84     return outfile
#
# TypeError: sequence item 0: expected a bytes-like object, str found

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineTwo
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-02-15 10:10:11.671129

# %%
#### char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/WT_E_L1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.dna.sort.bam')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/hisat2/'
#for i in range(246):
#    splitfile = os.path.join(path, f'WT_E_L1_R1R2.trim.AssUnFUnR.split{i}.DNA20RNA20RNAmax300.rna.sort.bam')
#    altreadfile2.append(splitfile)
    

steps=['sequences in features']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'normalize', 'summarizecontacts', 'heatmap', 'sequences in features', 'cumulative distribution']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  # --no-softclip
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''  # scaffold51_2  # leave blank and it will skip
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
buffer = 500


CharSeqPipelineTwo.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, buffer, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Number of scaffolds: 511
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109']
# Count: 0 | Current contact: pt0 1 2 pt14 347015 347016 1 A00574:219:HLYFTDRXX:1:2141:26259:15060:1:AACAT
# Count: 1000000 | Current contact: pt10 305116 305117 pt57 413277 413278 1 A00574:219:HLYFTDRXX:1:2114:24858:25316:1:TACAT
# Count: 2000000 | Current contact: pt22 307791 307792 pt66 41199 41200 3 A00574:219:HLYFTDRXX:1:2118:17318:24251:2:AACAT,A00574:219:HLYFTDRXX:1:2118:17409:24283:2:AACAT,A00574:219:HLYFTDRXX:1:2118:18159:26115:2:AACAT
# Count: 3000000 | Current contact: pt37 78379 78380 pt177 13450 13451 1 A00574:219:HLYFTDRXX:1:2125:13901:28729:1:AACAT
# Count: 4000000 | Current contact: pt52 432319 432320 pt4 194812 194813 3 A00574:219:HLYFTDRXX:1:2238:21540:8234:1:TACAT,A00574:219:HLYFTDRXX:1:2238:21992:8422:1:TACAT,A00574:219:HLYFTDRXX:1:2238:21206:8437:1:TACAT
# Count: 5000000 | Current contact: pt70 28112 28113 pt41 232538 232539 1 A00574:219:HLYFTDRXX:1:2252:14877:11224:1:TTTAT
# Count: 6000000 | Current contact: pt90 313610 313611 pt7 426887 426888 1 A00574:219:HLYFTDRXX:1:2151:3242:26365:1:AACAT
# Count: 7000000 | Current contact: pt115 72513 72514 pt90 17696 17697 2 A00574:219:HLYFTDRXX:1:2116:24713:14011:1:AACAT,A00574:219:HLYFTDRXX:1:2116:24189:15953:1:AACAT
# Count: 8000000 | Current contact: pt143 202876 202877 pt143 202540 202541 3 A00574:219:HLYFTDRXX:1:2205:12319:3129:1:CTCAG,A00574:219:HLYFTDRXX:1:2205:12617:3490:1:CTCAG,A00574:219:HLYFTDRXX:1:2205:15266:6167:1:CTCAG
# Count: 9000000 | Current contact: pt181 104324 104325 pt149 209477 209478 1 A00574:219:HLYFTDRXX:1:2278:26124:31861:2:TGAAC
# ['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split100.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E/pear/WT_E_L1_R1R2.trim.AssUnFUnR.split101.DNA20RNA20RNAmax300.rna.fastq.gz']
# 246
# Total Number of RNAs (after pear, before alignment): 21474325
# Total Number of Contacts in features: 7121930
# Number of unique rna sequences from contacts in features: 7121930
# Number of unique short rna sequences (<=30bps) from contacts in features: 335776
# Number of unique short rna sequences (==25bps) from contacts in features: 30081
# ##########
#     Fin
# ##########
