# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineFour
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2022-03-15 20:19:42.936913

# %%
# char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/NOWA_E_S1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/NOWA_E_S1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'  # '/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

#altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/EV_E_sRNA20to30bps/pear/WT_L_L1_R1R2.trim.AssUnFUnR.fastq.gz'
altreadfile1 = []
path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/'
for i in range(181):
    splitfile = os.path.join(path, f'NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split{i}.fastq.gz')
    altreadfile1.append(splitfile)
    
#altreadfile2='/path/to/altreads2.fastq'
altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/'
#for i in range(181):
#    splitfile = os.path.join(path, f'NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split{i}.fastq.gz')
#    altreadfile2.append(splitfile)
   
steps=['charbridge', 'hisat2', 'samtools', 'rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  #--no-softclip 
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip 
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 2000
rnabuffer = 15
rnamatch = 15
maxgapoverlap = 0.75

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, rnamatch, maxgapoverlap, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split0.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split0.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split1.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split1.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split2.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split2.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split2.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split3.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split3.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split3.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split4.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split4.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split4.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split5.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split5.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split5.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split6.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split6.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split6.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split7.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split7.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split7.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split8.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split8.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split8.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split9.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split9.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split9.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split10.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split10.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split11.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split11.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split11.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split12.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split12.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split12.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split13.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split13.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split13.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split14.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split14.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split14.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split15.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split15.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split15.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split16.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split16.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split16.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split17.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split17.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split17.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split18.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split18.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split18.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split19.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split19.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split19.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split20.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split20.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split20.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split21.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split21.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split21.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split22.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split22.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split22.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split23.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split23.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split23.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split24.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split24.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split24.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split25.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split25.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split25.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split26.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split26.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split26.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split27.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split27.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split27.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split28.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split28.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split28.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split29.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split29.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split29.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split30.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split30.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split30.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split31.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split31.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split31.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split32.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split32.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split32.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split33.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split33.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split33.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split34.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split34.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split34.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split35.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split35.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split35.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split36.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split36.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split36.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split37.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split37.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split37.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split38.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split38.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split38.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split39.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split39.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split39.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split40.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split40.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split40.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split41.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split41.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split41.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split42.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split42.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split42.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split43.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split43.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split43.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split44.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split44.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split44.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split45.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split45.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split45.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split46.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split46.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split46.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split47.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split47.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split47.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split48.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split48.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split48.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split49.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split49.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split49.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split50.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split50.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split50.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split51.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split51.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split51.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split52.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split52.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split52.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split53.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split53.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split53.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split54.fastq.gz
# python2 /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/char_bridge_trackall_simple.py --FASTQGZ /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split54.fastq.gz --NAME /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300. --minRNA 20 --minDNA 20 --maxRNA 300
# Finished Charseq Bridge Removal, output files:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300.rna.fastq.gz
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split54.DNA20RNA20RNAmax300.dna.fastq.gz
#
# Start Charseq Bridge Removal on file:
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split55.fastq.gz
# ...
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split119.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split120.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split121.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split122.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split123.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split124.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split125.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split126.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split127.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split128.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split129.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split130.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split131.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split132.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split133.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split134.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split135.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split136.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split137.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split138.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split139.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split140.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split141.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split142.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split143.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split144.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split145.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split146.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split147.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split148.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split149.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split150.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split151.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split152.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split153.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split154.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split155.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split156.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split157.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split158.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split159.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split160.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split161.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split162.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split163.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split164.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split165.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split166.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split167.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split168.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split169.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split170.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split171.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split172.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split173.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split174.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split175.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split176.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split177.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split178.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split179.DNA20RNA20RNAmax300.dna.sort.bam
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split180.DNA20RNA20RNAmax300.dna.sort.bam
# Finished recording 3' rna and 5'dna read positions and raw RNA-DNA contacts
# Starting Summarize RNA DNA contacts, and sequence names
# Number of raw contacts = 26920372
# Number of unique contacts = 12889564
# Average contact strength = 2.088540155431169
# writing out unique, but not sorted contacts
# sorting contacts
# contacts sorted
# Finished summarizing RNA DNA contacts
# Counting lengths of all scaffolds
# Summing lengths of all scaffolds
# Converting coordinates for each scaffold to continuous genome coordinates
# /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv
# [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01]
# []
# [0.495, 0.495, 0.505, 0.524, 0.657, 0.705, 0.838, 0.971, 1.0, 1.0]
# scaffold51_0
# Maximum coordinate length: 40469, Minimum coordinate length: 0, Window size: 20000
# 3
# (3, 3)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.20000.log.pdf
# Maximum coordinate length: 40469, Minimum coordinate length: 0, Window size: 20000
# 3
# (3, 3)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.20000.log.UniqueContacts.pdf
# Maximum coordinate length: 40469, Minimum coordinate length: 0, Window size: 5000
# 9
# (9, 9)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.5000.log.pdf
# Maximum coordinate length: 40469, Minimum coordinate length: 0, Window size: 5000
# 9
# (9, 9)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.40469.5000.log.UniqueContacts.pdf
# ['scaffold51_0', 'scaffold51_1', 'scaffold51_2']
# Maximum coordinate length: 3000000, Minimum coordinate length: 0, Window size: 5000
# 600
# (600, 600)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.3000000.5000.log.pdf
# Maximum coordinate length: 3000000, Minimum coordinate length: 0, Window size: 5000
# 600
# (600, 600)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.3000000.5000.log.UniqueContacts.pdf
# Maximum coordinate length: 75698530, Minimum coordinate length: 0, Window size: 50000
# 1514
# (1514, 1514)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.75698530.50000.log.pdf
# Maximum coordinate length: 3000000, Minimum coordinate length: 0, Window size: 50000
# 60
# (60, 60)
# Plotting heatmap
# Finished making heatmap: /media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.Unique.Strength.sort.gencoords.tsv.3000000.50000.log.UniqueContacts.pdf
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Features kept: internal_eliminated_sequence
# Number of scaffolds: 511
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109']
# Count: 0 | Current contact: pt0 1 31 - 1S31M pt111 231529 231658 - 45M31N54M 1 A00574:280:HVV7FDRXX:2:2177:27335:26287:1:TTTAA
# Count: 1000000 | Current contact: pt7 138407 138443 + 37M1S pt7 138136 138228 - 93M 1 A00574:280:HVV7FDRXX:2:2126:25898:25207:1:AATTC
# Count: 2000000 | Current contact: pt15 108791 108872 + 82M pt15 108504 108551 + 48M 1 A00574:280:HVV7FDRXX:2:2254:31720:27336:1:AAAGG
# Count: 3000000 | Current contact: pt24 231799 231863 - 9M1D55M pt22 341275 341334 + 60M5S 1 A00574:280:HVV7FDRXX:2:2220:10384:17159:1:AAGAA
# Count: 4000000 | Current contact: pt34 296837 296946 - 4S110M pt68 100130 100270 + 141M 4 A00574:280:HVV7FDRXX:2:2118:10610:3959:1:AACAT,A00574:280:HVV7FDRXX:2:2118:10610:4053:1:AACAT,A00574:280:HVV7FDRXX:2:2224:4128:30968:1:AACAT,A00574:280:HVV7FDRXX:2:2243:1262:17895:1:AACAT
# Count: 5000000 | Current contact: pt45 359075 359106 + 32M5S pt127 88966 89059 + 94M 1 A00574:280:HVV7FDRXX:2:2258:2537:33379:1:ATAAA
# Count: 6000000 | Current contact: pt57 323130 323265 - 136M pt99 151859 151915 - 57M 5 A00574:280:HVV7FDRXX:2:2140:5095:18584:1:AATTT,A00574:280:HVV7FDRXX:2:2218:9751:4695:1:AATTT,A00574:280:HVV7FDRXX:2:2218:9905:4867:1:AATTT,A00574:280:HVV7FDRXX:2:2218:9896:4883:1:AATTT,A00574:280:HVV7FDRXX:2:2236:6849:33646:1:AATTT
# Count: 7000000 | Current contact: pt70 190201 190297 + 97M13S pt85 253567 253587 - 21M 2 A00574:280:HVV7FDRXX:2:2246:28754:3067:2:AAGGT,A00574:280:HVV7FDRXX:2:2246:28718:3067:2:AAGGT
# Count: 8000000 | Current contact: pt85 147136 147236 - 1S101M pt85 311206 311336 + 131M 4 A00574:280:HVV7FDRXX:2:2156:6506:16767:1:AATCT,A00574:280:HVV7FDRXX:2:2227:15130:23156:1:AATCT,A00574:280:HVV7FDRXX:2:2227:14525:24549:1:AATCT,A00574:280:HVV7FDRXX:2:2242:17499:19680:1:AATCT
# Count: 9000000 | Current contact: pt101 289605 289669 + 65M pt32 405871 405936 - 66M 4 A00574:280:HVV7FDRXX:2:2125:2989:24173:2:ATTTA,A00574:280:HVV7FDRXX:2:2209:7862:11099:2:ATTTA,A00574:280:HVV7FDRXX:2:2209:7835:11146:2:ATTTA,A00574:280:HVV7FDRXX:2:2209:7835:11177:2:ATTTA
# Count: 10000000 | Current contact: pt120 62637 62699 + 63M pt63 107059 107259 - 201M 4 A00574:280:HVV7FDRXX:2:2150:26124:31704:1:AATCT,A00574:280:HVV7FDRXX:2:2178:19298:24392:1:AATCT,A00574:280:HVV7FDRXX:2:2232:23945:2472:1:AATCT,A00574:280:HVV7FDRXX:2:2232:24044:2613:1:AATCT
# Count: 11000000 | Current contact: pt140 186900 186965 + 66M4S pt16 79163 79223 - 61M 1 A00574:280:HVV7FDRXX:2:2235:8079:3521:2:AATCA
# Count: 12000000 | Current contact: pt164 140133 140260 + 128M3S pt164 80894 80953 - 60M 1 A00574:280:HVV7FDRXX:2:2260:21685:36949:1:AATGG
# Number of unique contacts inside features = 592
# Number of unique features, with contacts inside = 521
# ['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split100.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split101.DNA20RNA20RNAmax300.rna.fastq.gz']
# 181
# Total Number of RNAs (after pear, before alignment): 43396259
# Total strength of all contacts in all features: 1216
# Number of unique rna sequences from contacts in features: 1216
# Number of unique short rna sequences (<=30bps) from contacts in features: 18
# Number of unique short rna sequences (>=25bps, <=30bps) from contacts in features: 12
# Number of unique short rna sequences (==25bps) from contacts in features: 3
# ##########
#     Fin
# ##########

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineFour
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-03-17 07:55:06.482340

# %%
# char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/NOWA_E_S1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/NOWA_E_S1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'  # '/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/'
#for i in range(181):
#    splitfile = os.path.join(path, f'NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split{i}.fastq.gz')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/'
#for i in range(181):
#    splitfile = os.path.join(path, f'NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split{i}.fastq.gz')
#    altreadfile2.append(splitfile)
   
steps=['contacts in features', 'get sequences']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  #--no-softclip 
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip 
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.MDS.gff3'
features=['mds']


zoomscaffname = ''
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 0
rnabuffer = 0
rnamatch = 20
maxgapoverlap = 0.25

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, rnamatch, maxgapoverlap, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features)
# Out:
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.MDS.gff3
# Features kept: mds
# Number of scaffolds: 697
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109']
# Count: 0 | Current contact: pt0 1 31 - 1S31M pt111 231529 231658 - 45M31N54M 1 A00574:280:HVV7FDRXX:2:2177:27335:26287:1:TTTAA
# Count: 1000000 | Current contact: pt7 138407 138443 + 37M1S pt7 138136 138228 - 93M 1 A00574:280:HVV7FDRXX:2:2126:25898:25207:1:AATTC
# Count: 2000000 | Current contact: pt15 108791 108872 + 82M pt15 108504 108551 + 48M 1 A00574:280:HVV7FDRXX:2:2254:31720:27336:1:AAAGG
# Count: 3000000 | Current contact: pt24 231799 231863 - 9M1D55M pt22 341275 341334 + 60M5S 1 A00574:280:HVV7FDRXX:2:2220:10384:17159:1:AAGAA
# Count: 4000000 | Current contact: pt34 296837 296946 - 4S110M pt68 100130 100270 + 141M 4 A00574:280:HVV7FDRXX:2:2118:10610:3959:1:AACAT,A00574:280:HVV7FDRXX:2:2118:10610:4053:1:AACAT,A00574:280:HVV7FDRXX:2:2224:4128:30968:1:AACAT,A00574:280:HVV7FDRXX:2:2243:1262:17895:1:AACAT
# Count: 5000000 | Current contact: pt45 359075 359106 + 32M5S pt127 88966 89059 + 94M 1 A00574:280:HVV7FDRXX:2:2258:2537:33379:1:ATAAA
# Count: 6000000 | Current contact: pt57 323130 323265 - 136M pt99 151859 151915 - 57M 5 A00574:280:HVV7FDRXX:2:2140:5095:18584:1:AATTT,A00574:280:HVV7FDRXX:2:2218:9751:4695:1:AATTT,A00574:280:HVV7FDRXX:2:2218:9905:4867:1:AATTT,A00574:280:HVV7FDRXX:2:2218:9896:4883:1:AATTT,A00574:280:HVV7FDRXX:2:2236:6849:33646:1:AATTT
# Count: 7000000 | Current contact: pt70 190201 190297 + 97M13S pt85 253567 253587 - 21M 2 A00574:280:HVV7FDRXX:2:2246:28754:3067:2:AAGGT,A00574:280:HVV7FDRXX:2:2246:28718:3067:2:AAGGT
# Count: 8000000 | Current contact: pt85 147136 147236 - 1S101M pt85 311206 311336 + 131M 4 A00574:280:HVV7FDRXX:2:2156:6506:16767:1:AATCT,A00574:280:HVV7FDRXX:2:2227:15130:23156:1:AATCT,A00574:280:HVV7FDRXX:2:2227:14525:24549:1:AATCT,A00574:280:HVV7FDRXX:2:2242:17499:19680:1:AATCT
# Count: 9000000 | Current contact: pt101 289605 289669 + 65M pt32 405871 405936 - 66M 4 A00574:280:HVV7FDRXX:2:2125:2989:24173:2:ATTTA,A00574:280:HVV7FDRXX:2:2209:7862:11099:2:ATTTA,A00574:280:HVV7FDRXX:2:2209:7835:11146:2:ATTTA,A00574:280:HVV7FDRXX:2:2209:7835:11177:2:ATTTA
# Count: 10000000 | Current contact: pt120 62637 62699 + 63M pt63 107059 107259 - 201M 4 A00574:280:HVV7FDRXX:2:2150:26124:31704:1:AATCT,A00574:280:HVV7FDRXX:2:2178:19298:24392:1:AATCT,A00574:280:HVV7FDRXX:2:2232:23945:2472:1:AATCT,A00574:280:HVV7FDRXX:2:2232:24044:2613:1:AATCT
# Count: 11000000 | Current contact: pt140 186900 186965 + 66M4S pt16 79163 79223 - 61M 1 A00574:280:HVV7FDRXX:2:2235:8079:3521:2:AATCA
# Count: 12000000 | Current contact: pt164 140133 140260 + 128M3S pt164 80894 80953 - 60M 1 A00574:280:HVV7FDRXX:2:2260:21685:36949:1:AATGG
# Number of unique contacts inside features = 327008
# Number of unique features, with contacts inside = 30152
# ['/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split0.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split1.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split10.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split100.DNA20RNA20RNAmax300.rna.fastq.gz', '/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split101.DNA20RNA20RNAmax300.rna.fastq.gz']
# 181
# Retrieved sequences from 1 files
# Retrieved sequences from 2 files
# Retrieved sequences from 3 files
# Retrieved sequences from 4 files
# Retrieved sequences from 5 files
# Retrieved sequences from 6 files
# Retrieved sequences from 7 files
# Retrieved sequences from 8 files
# Retrieved sequences from 9 files
# Retrieved sequences from 10 files
# Retrieved sequences from 11 files
# Retrieved sequences from 12 files
# Retrieved sequences from 13 files
# Retrieved sequences from 14 files
# Retrieved sequences from 15 files
# Retrieved sequences from 16 files
# Retrieved sequences from 17 files
# Retrieved sequences from 18 files
# Retrieved sequences from 19 files
# Retrieved sequences from 20 files
# Retrieved sequences from 21 files
# Retrieved sequences from 22 files
# Retrieved sequences from 23 files
# Retrieved sequences from 24 files
# Retrieved sequences from 25 files
# Retrieved sequences from 26 files
# Retrieved sequences from 27 files
# Retrieved sequences from 28 files
# Retrieved sequences from 29 files
# Retrieved sequences from 30 files
# Retrieved sequences from 31 files
# Retrieved sequences from 32 files
# Retrieved sequences from 33 files
# Retrieved sequences from 34 files
# Retrieved sequences from 35 files
# Retrieved sequences from 36 files
# Retrieved sequences from 37 files
# Retrieved sequences from 38 files
# Retrieved sequences from 39 files
# Retrieved sequences from 40 files
# Retrieved sequences from 41 files
# Retrieved sequences from 42 files
# Retrieved sequences from 43 files
# Retrieved sequences from 44 files
# Retrieved sequences from 45 files
# Retrieved sequences from 46 files
# Retrieved sequences from 47 files
# Retrieved sequences from 48 files
# Retrieved sequences from 49 files
# Retrieved sequences from 50 files
# Retrieved sequences from 51 files
# Retrieved sequences from 52 files
# Retrieved sequences from 53 files
# Retrieved sequences from 54 files
# Retrieved sequences from 55 files
# Retrieved sequences from 56 files
# Retrieved sequences from 57 files
# Retrieved sequences from 58 files
# Retrieved sequences from 59 files
# Retrieved sequences from 60 files
# Retrieved sequences from 61 files
# Retrieved sequences from 62 files
# Retrieved sequences from 63 files
# Retrieved sequences from 64 files
# Retrieved sequences from 65 files
# Retrieved sequences from 66 files
# Retrieved sequences from 67 files
# Retrieved sequences from 68 files
# Retrieved sequences from 69 files
# Retrieved sequences from 70 files
# Retrieved sequences from 71 files
# Retrieved sequences from 72 files
# Retrieved sequences from 73 files
# Retrieved sequences from 74 files
# Retrieved sequences from 75 files
# Retrieved sequences from 76 files
# Retrieved sequences from 77 files
# Retrieved sequences from 78 files
# Retrieved sequences from 79 files
# Retrieved sequences from 80 files
# Retrieved sequences from 81 files
# Retrieved sequences from 82 files
# Retrieved sequences from 83 files
# Retrieved sequences from 84 files
# Retrieved sequences from 85 files
# Retrieved sequences from 86 files
# Retrieved sequences from 87 files
# Retrieved sequences from 88 files
# Retrieved sequences from 89 files
# Retrieved sequences from 90 files
# Retrieved sequences from 91 files
# Retrieved sequences from 92 files
# Retrieved sequences from 93 files
# Retrieved sequences from 94 files
# Retrieved sequences from 95 files
# Retrieved sequences from 96 files
# Retrieved sequences from 97 files
# Retrieved sequences from 98 files
# Retrieved sequences from 99 files
# Retrieved sequences from 100 files
# Retrieved sequences from 101 files
# Retrieved sequences from 102 files
# Retrieved sequences from 103 files
# Retrieved sequences from 104 files
# Retrieved sequences from 105 files
# Retrieved sequences from 106 files
# Retrieved sequences from 107 files
# Retrieved sequences from 108 files
# Retrieved sequences from 109 files
# Retrieved sequences from 110 files
# Retrieved sequences from 111 files
# Retrieved sequences from 112 files
# Retrieved sequences from 113 files
# Retrieved sequences from 114 files
# Retrieved sequences from 115 files
# Retrieved sequences from 116 files
# Retrieved sequences from 117 files
# Retrieved sequences from 118 files
# Retrieved sequences from 119 files
# Retrieved sequences from 120 files
# Retrieved sequences from 121 files
# Retrieved sequences from 122 files
# Retrieved sequences from 123 files
# Retrieved sequences from 124 files
# Retrieved sequences from 125 files
# Retrieved sequences from 126 files
# Retrieved sequences from 127 files
# Retrieved sequences from 128 files
# Retrieved sequences from 129 files
# Retrieved sequences from 130 files
# Retrieved sequences from 131 files
# Retrieved sequences from 132 files
# Retrieved sequences from 133 files
# Retrieved sequences from 134 files
# Retrieved sequences from 135 files
# Retrieved sequences from 136 files
# Retrieved sequences from 137 files
# Retrieved sequences from 138 files
# Retrieved sequences from 139 files
# Retrieved sequences from 140 files
# Retrieved sequences from 141 files
# Retrieved sequences from 142 files
# Retrieved sequences from 143 files
# Retrieved sequences from 144 files
# Retrieved sequences from 145 files
# Retrieved sequences from 146 files
# Retrieved sequences from 147 files
# Retrieved sequences from 148 files
# Retrieved sequences from 149 files
# Retrieved sequences from 150 files
# Retrieved sequences from 151 files
# Retrieved sequences from 152 files
# Retrieved sequences from 153 files
# Retrieved sequences from 154 files
# Retrieved sequences from 155 files
# Retrieved sequences from 156 files
# Retrieved sequences from 157 files
# Retrieved sequences from 158 files
# Retrieved sequences from 159 files
# Retrieved sequences from 160 files
# Retrieved sequences from 161 files
# Retrieved sequences from 162 files
# Retrieved sequences from 163 files
# Retrieved sequences from 164 files
# Retrieved sequences from 165 files
# Retrieved sequences from 166 files
# Retrieved sequences from 167 files
# Retrieved sequences from 168 files
# Retrieved sequences from 169 files
# Retrieved sequences from 170 files
# Retrieved sequences from 171 files
# Retrieved sequences from 172 files
# Retrieved sequences from 173 files
# Retrieved sequences from 174 files
# Retrieved sequences from 175 files
# Retrieved sequences from 176 files
# Retrieved sequences from 177 files
# Retrieved sequences from 178 files
# Retrieved sequences from 179 files
# Retrieved sequences from 180 files
# Retrieved sequences from 181 files
# Total Number of RNAs (after pear, before alignment): 43396259
# Total strength of all contacts in all features: 674933
# Number of unique rna sequences from contacts in features: 674933
# Number of unique short rna sequences (<=30bps) from contacts in features: 33001
# Number of unique short rna sequences (>=25bps, <=30bps) from contacts in features: 18931
# Number of unique short rna sequences (==25bps) from contacts in features: 3026
# ##########
#     Fin
# ##########

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
print(datetime.datetime.now())

from pygentoolbox import CharSeqPipelineFour
# from pygentoolbox.Tools import read_interleaved_fasta_as_noninterleaved
# from pygentoolbox.Tools import make_circos_karyotype_file
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2022-03-24 14:53:06.203155

# %%
# char_bridge_tools.py requires python2 i'm running python 2.7.17
# pip install Python-Levenshtein
# pip install biopython
# RecordRNADNAContacts.py uses python3 i'm running python 3.7 anaconda
# pip install natsort
forwardreadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/NOWA_E_S1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/NOWA_E_S1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'  # '/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/'
#for i in range(181):
#    splitfile = os.path.join(path, f'NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split{i}.fastq.gz')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/'
#for i in range(181):
#    splitfile = os.path.join(path, f'NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split{i}.fastq.gz')
#    altreadfile2.append(splitfile)
   
steps=['trans rna']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  #--no-softclip 
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip 
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 1000
rnabuffer = 0
rnamatch = 20
maxgapoverlap = 0.25
rnalocation = [387, 20, 6208]  # add 223 to 5985 (=) because 223 extra bases are added to the Mac+IES genome as IESs inside of the lnc1 coordinates for the Mac 
                               # no IESs inside the lnc15 coordinates, so don't need to change them

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, rnamatch, maxgapoverlap, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features, rnalocation)
# Out:
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Features kept: internal_eliminated_sequence
# Number of scaffolds: 511
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109']
# Count: 0 | Current contact: pt0 1 31 - 1S31M pt111 231529 231658 - 45M31N54M 1 A00574:280:HVV7FDRXX:2:2177:27335:26287:1:TTTAA
# Count: 1000000 | Current contact: pt7 138407 138443 + 37M1S pt7 138136 138228 - 93M 1 A00574:280:HVV7FDRXX:2:2126:25898:25207:1:AATTC
# Count: 2000000 | Current contact: pt15 108791 108872 + 82M pt15 108504 108551 + 48M 1 A00574:280:HVV7FDRXX:2:2254:31720:27336:1:AAAGG
# Count: 3000000 | Current contact: pt24 231799 231863 - 9M1D55M pt22 341275 341334 + 60M5S 1 A00574:280:HVV7FDRXX:2:2220:10384:17159:1:AAGAA
file='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/NOWA_E_S1_R1.fastq.gz'
reversereadfile='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/NOWA_E_S1_R2.fastq.gz'
blastdatabase='/media/sf_LinuxShare/Ciliates/Genomes/Seqs/IESs'  # '/media/sf_LinuxShare/Humans/Genome/Seqs/GRCh38_top_level.fa'
aligndatabase='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES_mtDNA'

altreadfile1='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/hisat2/RNA.DNA.Contacts.Unique.Strength.AllSeqNames.sort.txt'
#altreadfile1 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/'
#for i in range(181):
#    splitfile = os.path.join(path, f'NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split{i}.fastq.gz')
#    altreadfile1.append(splitfile)
    
altreadfile2='/path/to/altreads2.fastq'
#altreadfile2 = []
#path ='/media/sf_LinuxShare/Projects/Lyna/CharSeqPipe/Nowa1_E/pear/'
#for i in range(181):
#    splitfile = os.path.join(path, f'NOWA_E_S1_L002_R1_R1R2.trim.AssUnFUnR.split{i}.fastq.gz')
#    altreadfile2.append(splitfile)
   
steps=['trans rna']
# steps=['fastp', 'fastqc', 'pear', 'mergefiles', 'split2chunks', 'charbridge', 'fastq2fasta', 'blast', 'hisat2', 'samtools', 'rnadnacontacts', 'summarizecontacts', 'heatmap', 'contacts in features', 'get sequences']
rnalen=20
dnalen=20
rnamaxlen=300
REsequence='GATC'
windowsize=300
contactcutoff=1
MQ=1
sn='Paramecium tetraurelia'

# if mapping to Mac
# hisat2_args='-p 2'  #--no-softclip 
# if mapping to Mac+IES
hisat2_args='-p 2 --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'  # --no-softclip 
genomefile = '/media/sf_LinuxShare/Ciliates/Genomes/Seqs/ptetraurelia_mac_51_with_ies_with_mtDNA.fa'
PCRDupRemoval=False

# ptetraurelia_mac_51_annotation_v2.0.gff3
annot_file = '/media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3'
features=['internal_eliminated_sequence']


zoomscaffname = ''
zoomwinsize = 50
scaffcoordmin, scaffcoordmax = [219999, 354999, 474999, 629999, 839999], [239999, 374999, 484999, 649999, 859999]
dnabuffer = 1000
rnabuffer = 0
rnamatch = 20
maxgapoverlap = 0.25
rnalocation = [357, 21, 979]

CharSeqPipelineFour.main(forwardreadfile, reversereadfile, blastdatabase, aligndatabase, altreadfile1, altreadfile2, steps, rnalen, dnalen, rnamaxlen, REsequence, windowsize, contactcutoff, MQ, dnabuffer, rnabuffer, rnamatch, maxgapoverlap, sn, hisat2_args, genomefile, PCRDupRemoval, annot_file, zoomscaffname, zoomwinsize, scaffcoordmin, scaffcoordmax, features, rnalocation)
# Out:
# Reading Gff3 file and indexing by scaffold: /media/sf_LinuxShare/Ciliates/Genomes/Annotations/internal_eliminated_sequence_PGM_ParTIES.pt_51_with_ies.gff3
# Features kept: internal_eliminated_sequence
# Number of scaffolds: 511
# ['100', '101', '102', '103', '104', '105', '106', '107', '108', '109']
# Count: 0 | Current contact: pt0 1 31 - 1S31M pt111 231529 231658 - 45M31N54M 1 A00574:280:HVV7FDRXX:2:2177:27335:26287:1:TTTAA
# Count: 1000000 | Current contact: pt7 138407 138443 + 37M1S pt7 138136 138228 - 93M 1 A00574:280:HVV7FDRXX:2:2126:25898:25207:1:AATTC
