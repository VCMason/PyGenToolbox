# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pygentoolbox.test_ruptures
# Out:
# rows: 1000 columns: 3
# Input data format:
# <class 'numpy.ndarray'>
# [[ 10.48464735 -13.2213443    1.79345419]
#  [  6.37841851  -7.27781337   0.34444991]
#  [  6.3063126   -7.11433517  10.40818696]
#  ...
#  [  8.33226818 -10.08627717  -0.9829606 ]
#  [  5.10945967   2.10391815  -1.40619239]
#  [ 17.98486555   0.07058131  -4.0220189 ]]
# Generated Break Points
# [199, 401, 613, 802, 1000]
# Result:
# [200, 405, 615, 800, 1000]
