# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pygentoolbox.test_rupturesMimicMassSpec
# Out:
# Keep the number of genes < 100 for plotting. Note: time points are rows in the data matrix but columns in the plot. genes are columns in data matrix but rows in plot
# How many time points would you like to generate in the data matrix? (ex: 15) :  25
# How many genes would you like to generate in the data matrix? (ex: 50) :  50
# Do you want the plot? (y/n):  y
# How many break points? (ex: 1) :  1
# Which Model : l1, l2, or rbf ? :  rbf
# penalty for model? ex: (integers 1-10) :  1
# rows: 25 columns: 50
# Input data format:
# [[ -2.68306582  -4.62358458   3.26503535 ...  -6.88809739   4.30087857
#    -1.42711596]
#  [  1.79243332  -5.56996009   2.71886381 ... -13.38046212   6.16423378
#    -2.62269439]
#  [ -1.14986111  -7.98202906   0.84993523 ...  -5.33715623   2.06687437
#     4.25772701]
#  ...
#  [ -6.60540838 -12.21789338 -10.80222222 ... -22.64190241  13.26604483
#    -7.84308731]
#  [-18.17720486 -14.02573831   0.46747276 ... -17.57040758  14.45988194
#    -4.47669533]
# ...
