# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pygentoolbox.RunRuptures
# Out:
# Keep the number of genes < 100 for plotting. Note: time points are rows in the data matrix but columns in the plot. genes are columns in data matrix but rows in plot
# Do you want the plot? (y/n):  y
# Which Model : l1, l2, or rbf ? :  rbf
# penalty for model? ex: (integers 1-10) :  1
# Enter all expected breakpoints (according to your hypothesis) (ex: 3,7,20) 7
# Enter full path to gene expression matrix:  D:\\LinuxShare\\Projects\\Perwin\\MASS_SPEC\\LFQMatrix.small.t.tsv
# rows: 14 columns: 100
# Input data format:
# [[ 5.11013e-01  7.58860e-01  2.55898e-01 ... -2.15081e+02 -1.84492e+02
#   -1.88636e+02]
#  [ 6.77297e-01  7.08484e-01  1.74791e+02 ...  1.61573e+02  4.95704e-01
#    2.52734e-01]
#  [-1.26775e+02 -1.29268e+02 -3.94978e-01 ...  8.84943e-02  4.73524e-01
#   -6.45463e-01]
#  ...
#  [-2.72202e-01 -1.29268e+02  2.65220e-01 ...  3.16907e-01  5.13828e-01
#    9.54005e-01]
#  [-3.23343e-01  7.24049e-01  4.63068e-01 ...  2.20730e-01  4.98470e-01
#    4.33540e-01]
# ...
