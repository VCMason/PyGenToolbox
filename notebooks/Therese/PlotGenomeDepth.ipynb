# %%
# %load_ext autoreload
# %autoreload 2
import datetime
print(datetime.datetime.now())

import pygentoolbox.Tools
import pygentoolbox.PlotGenomeDepth
#dir(pygentoolbox.Tools)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2019-06-27 12:58:08.300634

# %%
bedfile = 'D:\\LinuxShare\\Projects\\Theresa\\bedtools\\genomecov\\52_Late.genomecov.tsv'
outpath = 'D:\\LinuxShare\\Projects\\Theresa\\bedtools\\genomecov\\52_Late.genomecov.png'
cutoff = 5
pygentoolbox.PlotGenomeDepth.main(bedfile, outpath, cutoff)
# Out:
# Reading in Bedfile
# Formatting Data
# Plotting data

# %%
bedfile = 'D:\\LinuxShare\\Projects\\Theresa\\bedtools\\genomecov\\53_Later.genomecov.tsv'
outpath = 'D:\\LinuxShare\\Projects\\Theresa\\bedtools\\genomecov\\53_Later.genomecov.png'
cutoff = 5
pygentoolbox.PlotGenomeDepth.main(bedfile, outpath, cutoff)
# Out:
# Reading in Bedfile
# Formatting Data
# Plotting data
