# %%
# %load_ext autoreload
# %autoreload 2
import os
import glob
import datetime
import subprocess
print(datetime.datetime.now())

from pygentoolbox import ReadMapping
from pygentoolbox import ReadMapping_v2
from pygentoolbox import SplitFastqFileBySeqLength

from pygentoolbox import SeqsPerFeatureAndFeatureTypeFixed
from pygentoolbox import CalculateRelativeBaseCoverageOfFeatureType

# need pygentoolbox.Tools also
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2022-03-27 17:12:25.236036

# %%
fastqfile = '/media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/Ptiwi0109KD_total_sRNA_Early.fastq'
minlength=25
maxlength=25
onefile=True
SplitFastqFileBySeqLength.main(fastqfile, minlength, maxlength, onefile)

fastqfile = '/media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/Ptiwi09_RIP_Early.fastq'
minlength=25
maxlength=25
onefile=True
SplitFastqFileBySeqLength.main(fastqfile, minlength, maxlength, onefile)

# %%
# define variables:
# cell 1
forward = ['SeroA_sRNA.23bp.fastq', 'SeroB_sRNA.23bp.fastq', 'SeroD_sRNA.23bp.fastq', 'SeroH_sRNA.23bp.fastq']
# forward = []
# for i in range(15, 42): # align each seq length 15-41 and then 50bps # this is EV_late_totalsRNA
#     name = f'190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_{i}bp.fastq.gz'
#     forward.append(name)
# forward.append('190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_50bp.fastq.gz')
reverse = [''] * len(forward)
#forward = ['H3K4me3_Rep1_R1.fastq.gz', 'H3K4me3_Rep2_R1.fastq.gz', 'H3K9me3_Rep1_R1.fastq.gz', 'H3K9me3_Rep2_R1.fastq.gz', 'H3K27me3_Rep1_R1.fastq.gz', 'H3K27me3_Rep2_R1.fastq.gz']
#reverse = ['H3K4me3_Rep1_R2.fastq.gz', 'H3K4me3_Rep2_R2.fastq.gz', 'H3K9me3_Rep1_R2.fastq.gz', 'H3K9me3_Rep2_R2.fastq.gz', 'H3K27me3_Rep1_R2.fastq.gz', 'H3K27me3_Rep2_R2.fastq.gz']
directory='/media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA'
cleanreads=False  # are .fastq.gz reads already clean? if True skip fastp
paired=False
reference='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac'

skipsteps=[]
hisat_args='-p2'  # --no-spliced-alignment # --no-softclip # max-intronlen 6000
#hisat_args='-p 2 --no-softclip --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'

# %%
#fileextension='.fastq.gz'
#directory='/media/sf_LinuxShare/Projects/Ryuma/hisat2/2018-09-19_L1-4_ADPF-29_inserts'
#cleanreads=True  # are .fastq.gz reads already clean? if True skip fastp
#reference='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac'
print(datetime.datetime.now())

ReadMapping_v2.main(forward, reverse, directory, hisat_args, skipsteps, paired, reference)

print(datetime.datetime.now())
# Out:
# 2022-03-27 17:13:26.168756
# Start trimming of:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/SeroA_sRNA.23bp.fastq
#
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp  Created
# fastp -i /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/SeroA_sRNA.23bp.fastq -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroA_sRNA.trim.fastq.gz
# b''
# Finished trimming, files output to:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroA_sRNA.trim.fastq.gz
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroA_sRNA.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroA_sRNA.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroA_sRNA.trim.fastq
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc  Created
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroA_sRNA.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc
#
# Aligning reads to Reference:
# /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/hisat2  Created
# Starting Hisat2 single end: aligning
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroA_sRNA.trim.fastq.gz
# hisat2 -q -p2 -x /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac -U /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroA_sRNA.trim.fastq.gz -S /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/hisat2/SeroA_sRNA.trim.Pt_51_Mac.sam
# Finished with Hisat2
#
# Starting samtools converting sam to sorted indexed bam
# Finished with Samtools, returning /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/hisat2/SeroA_sRNA.trim.Pt_51_Mac.sort.bam
#
# Start trimming of:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/SeroB_sRNA.23bp.fastq
#
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp  already exists
# fastp -i /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/SeroB_sRNA.23bp.fastq -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroB_sRNA.trim.fastq.gz
# b''
# Finished trimming, files output to:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroB_sRNA.trim.fastq.gz
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroB_sRNA.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroB_sRNA.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroB_sRNA.trim.fastq
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc  already exists
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroB_sRNA.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc
#
# Aligning reads to Reference:
# /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/hisat2  already exists
# Starting Hisat2 single end: aligning
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroB_sRNA.trim.fastq.gz
# hisat2 -q -p2 -x /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac -U /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroB_sRNA.trim.fastq.gz -S /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/hisat2/SeroB_sRNA.trim.Pt_51_Mac.sam
# Finished with Hisat2
#
# Starting samtools converting sam to sorted indexed bam
# Finished with Samtools, returning /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/hisat2/SeroB_sRNA.trim.Pt_51_Mac.sort.bam
#
# Start trimming of:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/SeroD_sRNA.23bp.fastq
#
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp  already exists
# fastp -i /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/SeroD_sRNA.23bp.fastq -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroD_sRNA.trim.fastq.gz
# b''
# Finished trimming, files output to:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroD_sRNA.trim.fastq.gz
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroD_sRNA.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroD_sRNA.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroD_sRNA.trim.fastq
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc  already exists
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroD_sRNA.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc
#
# Aligning reads to Reference:
# /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/hisat2  already exists
# Starting Hisat2 single end: aligning
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroD_sRNA.trim.fastq.gz
# hisat2 -q -p2 -x /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac -U /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroD_sRNA.trim.fastq.gz -S /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/hisat2/SeroD_sRNA.trim.Pt_51_Mac.sam
# Finished with Hisat2
#
# Starting samtools converting sam to sorted indexed bam
# Finished with Samtools, returning /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/hisat2/SeroD_sRNA.trim.Pt_51_Mac.sort.bam
#
# Start trimming of:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/SeroH_sRNA.23bp.fastq
#
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp  already exists
# fastp -i /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/SeroH_sRNA.23bp.fastq -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroH_sRNA.trim.fastq.gz
# b''
# Finished trimming, files output to:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroH_sRNA.trim.fastq.gz
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroH_sRNA.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroH_sRNA.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroH_sRNA.trim.fastq
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc  already exists
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroH_sRNA.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/fastqc
#
# Aligning reads to Reference:
# /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/hisat2  already exists
# Starting Hisat2 single end: aligning
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroH_sRNA.trim.fastq.gz
# hisat2 -q -p2 -x /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac -U /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/SeroH_sRNA.trim.fastq.gz -S /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/hisat2/SeroH_sRNA.trim.Pt_51_Mac.sam
# Finished with Hisat2
#
# Starting samtools converting sam to sorted indexed bam
# Finished with Samtools, returning /media/sf_LinuxShare/Projects/Theresa/Hisat2/ENA/fastp/hisat2/SeroH_sRNA.trim.Pt_51_Mac.sort.bam
#
# ##########
# ###FIN####
# ##########
# 2022-03-27 17:19:43.992300

# %%
# define variables:
# cell 1
forward = ['EV_L_R1_23bp.fastq.gz']
# forward = []
# for i in range(15, 42): # align each seq length 15-41 and then 50bps # this is EV_late_totalsRNA
#     name = f'190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_{i}bp.fastq.gz'
#     forward.append(name)
# forward.append('190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_50bp.fastq.gz')
reverse = [''] * len(forward)
#forward = ['H3K4me3_Rep1_R1.fastq.gz', 'H3K4me3_Rep2_R1.fastq.gz', 'H3K9me3_Rep1_R1.fastq.gz', 'H3K9me3_Rep2_R1.fastq.gz', 'H3K27me3_Rep1_R1.fastq.gz', 'H3K27me3_Rep2_R1.fastq.gz']
#reverse = ['H3K4me3_Rep1_R2.fastq.gz', 'H3K4me3_Rep2_R2.fastq.gz', 'H3K9me3_Rep1_R2.fastq.gz', 'H3K9me3_Rep2_R2.fastq.gz', 'H3K27me3_Rep1_R2.fastq.gz', 'H3K27me3_Rep2_R2.fastq.gz']
directory='/media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1'
cleanreads=False  # are .fastq.gz reads already clean? if True skip fastp
paired=False
reference='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac'

skipsteps=[]
hisat_args='-p2'  # --no-spliced-alignment # --no-softclip # max-intronlen 6000
#hisat_args='-p 2 --no-softclip --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'

# %%
#fileextension='.fastq.gz'
#directory='/media/sf_LinuxShare/Projects/Ryuma/hisat2/2018-09-19_L1-4_ADPF-29_inserts'
#cleanreads=True  # are .fastq.gz reads already clean? if True skip fastp
#reference='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac'
print(datetime.datetime.now())

ReadMapping_v2.main(forward, reverse, directory, hisat_args, skipsteps, paired, reference)

print(datetime.datetime.now())
# Out:
# 2022-03-18 16:52:24.479173
# Start trimming of:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/EV_L_R1_23bp.fastq.gz
#
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp  already exists
# fastp -i /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/EV_L_R1_23bp.fastq.gz -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/EV_L_R1_23bp.trim.fastq.gz
# b''
# Finished trimming, files output to:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/EV_L_R1_23bp.trim.fastq.gz
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/EV_L_R1_23bp.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/EV_L_R1_23bp.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/EV_L_R1_23bp.trim.fastq
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/fastqc
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/fastqc  already exists
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/EV_L_R1_23bp.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/fastqc
#
# Aligning reads to Reference:
# /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/hisat2  already exists
# Starting Hisat2 single end: aligning
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/EV_L_R1_23bp.trim.fastq.gz
# hisat2 -q -p2 -x /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac -U /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/EV_L_R1_23bp.trim.fastq.gz -S /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/hisat2/EV_L_R1_23bp.trim.Pt_51_Mac.sam
# Finished with Hisat2
#
# Starting samtools converting sam to sorted indexed bam
# Finished with Samtools, returning /media/sf_LinuxShare/Projects/Theresa/Hisat2/Hen1/fastp/hisat2/EV_L_R1_23bp.trim.Pt_51_Mac.sort.bam
#
# ##########
# ###FIN####
# ##########
# 2022-03-18 16:54:24.261155

# %%
# define variables:
# cell 1
forward = ['InvertedClusters_L_R1_23bp.fastq.gz']
# forward = []
# for i in range(15, 42): # align each seq length 15-41 and then 50bps # this is EV_late_totalsRNA
#     name = f'190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_{i}bp.fastq.gz'
#     forward.append(name)
# forward.append('190118_NB501473_A_L1-4_ADPF-56_AdapterTrimmed_R1_50bp.fastq.gz')
reverse = [''] * len(forward)
#forward = ['H3K4me3_Rep1_R1.fastq.gz', 'H3K4me3_Rep2_R1.fastq.gz', 'H3K9me3_Rep1_R1.fastq.gz', 'H3K9me3_Rep2_R1.fastq.gz', 'H3K27me3_Rep1_R1.fastq.gz', 'H3K27me3_Rep2_R1.fastq.gz']
#reverse = ['H3K4me3_Rep1_R2.fastq.gz', 'H3K4me3_Rep2_R2.fastq.gz', 'H3K9me3_Rep1_R2.fastq.gz', 'H3K9me3_Rep2_R2.fastq.gz', 'H3K27me3_Rep1_R2.fastq.gz', 'H3K27me3_Rep2_R2.fastq.gz']
directory='/media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters'
cleanreads=False  # are .fastq.gz reads already clean? if True skip fastp
paired=False
reference='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac'

skipsteps=[]
hisat_args='-p2'  # --no-spliced-alignment # --no-softclip # max-intronlen 6000
#hisat_args='-p 2 --no-softclip --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'

# %%
#fileextension='.fastq.gz'
#directory='/media/sf_LinuxShare/Projects/Ryuma/hisat2/2018-09-19_L1-4_ADPF-29_inserts'
#cleanreads=True  # are .fastq.gz reads already clean? if True skip fastp
#reference='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac'
print(datetime.datetime.now())

ReadMapping_v2.main(forward, reverse, directory, hisat_args, skipsteps, paired, reference)

print(datetime.datetime.now())
# Out:
# 2022-03-17 17:20:11.235502
# Start trimming of:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/InvertedClusters_L_R1_23bp.fastq.gz
#
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp  Created
# fastp -i /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/InvertedClusters_L_R1_23bp.fastq.gz -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/InvertedClusters_L_R1_23bp.trim.fastq.gz
# b''
# Finished trimming, files output to:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/InvertedClusters_L_R1_23bp.trim.fastq.gz
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/InvertedClusters_L_R1_23bp.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/InvertedClusters_L_R1_23bp.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/InvertedClusters_L_R1_23bp.trim.fastq
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/fastqc
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/fastqc  Created
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/InvertedClusters_L_R1_23bp.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/fastqc
#
# Aligning reads to Reference:
# /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/hisat2  Created
# Starting Hisat2 single end: aligning
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/InvertedClusters_L_R1_23bp.trim.fastq.gz
# hisat2 -q -p2 -x /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac -U /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/InvertedClusters_L_R1_23bp.trim.fastq.gz -S /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/hisat2/InvertedClusters_L_R1_23bp.trim.Pt_51_Mac.sam
# Finished with Hisat2
#
# Starting samtools converting sam to sorted indexed bam
# Finished with Samtools, returning /media/sf_LinuxShare/Projects/Theresa/Hisat2/InvertedP08Clusters/fastp/hisat2/InvertedClusters_L_R1_23bp.trim.Pt_51_Mac.sort.bam
#
# ##########
# ###FIN####
# ##########
# 2022-03-17 17:24:56.629133
