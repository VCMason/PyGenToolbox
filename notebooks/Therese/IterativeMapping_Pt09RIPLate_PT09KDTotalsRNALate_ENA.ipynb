# %%
# %load_ext autoreload
# %autoreload 2
import os
import glob
import datetime
import subprocess
print(datetime.datetime.now())

from pygentoolbox import ReadMapping
from pygentoolbox import ReadMapping_v2
from pygentoolbox import SplitFastqFileBySeqLength

from pygentoolbox import SeqsPerFeatureAndFeatureTypeFixed
from pygentoolbox import CalculateRelativeBaseCoverageOfFeatureType

# need pygentoolbox.Tools also
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2021-01-21 16:31:33.278518

# %%
fastqfile = '/media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/Ptiwi0109KD_total_sRNA_Early.fastq'
minlength=25
maxlength=25
onefile=True
SplitFastqFileBySeqLength.main(fastqfile, minlength, maxlength, onefile)

fastqfile = '/media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/Ptiwi09_RIP_Early.fastq'
minlength=25
maxlength=25
onefile=True
SplitFastqFileBySeqLength.main(fastqfile, minlength, maxlength, onefile)
# Out:
# On sequence: 0
# On sequence: 1000000
# On sequence: 2000000
# On sequence: 3000000
# On sequence: 4000000
# On sequence: 5000000
# On sequence: 6000000
# On sequence: 7000000
# On sequence: 8000000
# On sequence: 9000000
# On sequence: 10000000
# On sequence: 11000000
# On sequence: 12000000
# On sequence: 13000000
# On sequence: 14000000
# On sequence: 15000000
# On sequence: 16000000
# On sequence: 17000000
# On sequence: 18000000
# On sequence: 19000000
# On sequence: 20000000
# On sequence: 21000000
# On sequence: 22000000
# On sequence: 23000000
# On sequence: 24000000
# On sequence: 25000000
# On sequence: 26000000
# On sequence: 27000000
# Made one fastq file for each sequence length:
# Input file: /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/Ptiwi0109KD_total_sRNA_Early.fastq
# Example output filename: /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/Ptiwi0109KD_total_sRNA_Early25bp25bp.fastq
# Number of lines in input file: 108524048
# On sequence: 0
# On sequence: 1000000
# On sequence: 2000000
# On sequence: 3000000
# On sequence: 4000000
# On sequence: 5000000
# On sequence: 6000000
# On sequence: 7000000
# On sequence: 8000000
# On sequence: 9000000
# On sequence: 10000000
# On sequence: 11000000
# On sequence: 12000000
# On sequence: 13000000
# On sequence: 14000000
# On sequence: 15000000
# On sequence: 16000000
# On sequence: 17000000
# On sequence: 18000000
# On sequence: 19000000
# On sequence: 20000000
# On sequence: 21000000
# On sequence: 22000000
# On sequence: 23000000
# On sequence: 24000000
# On sequence: 25000000
# On sequence: 26000000
# On sequence: 27000000
# On sequence: 28000000
# On sequence: 29000000
# On sequence: 30000000
# On sequence: 31000000
# On sequence: 32000000
# On sequence: 33000000
# On sequence: 34000000
# On sequence: 35000000
# On sequence: 36000000
# On sequence: 37000000
# On sequence: 38000000
# On sequence: 39000000
# On sequence: 40000000
# On sequence: 41000000
# On sequence: 42000000
# On sequence: 43000000
# On sequence: 44000000
# On sequence: 45000000
# On sequence: 46000000
# On sequence: 47000000
# On sequence: 48000000
# On sequence: 49000000
# On sequence: 50000000
# On sequence: 51000000
# On sequence: 52000000
# On sequence: 53000000
# On sequence: 54000000
# On sequence: 55000000
# On sequence: 56000000
# On sequence: 57000000
# On sequence: 58000000
# On sequence: 59000000
# On sequence: 60000000
# On sequence: 61000000
# On sequence: 62000000
# On sequence: 63000000
# On sequence: 64000000
# On sequence: 65000000
# On sequence: 66000000
# On sequence: 67000000
# On sequence: 68000000
# On sequence: 69000000
# On sequence: 70000000
# On sequence: 71000000
# On sequence: 72000000
# On sequence: 73000000
# On sequence: 74000000
# On sequence: 75000000
# On sequence: 76000000
# On sequence: 77000000
# On sequence: 78000000
# On sequence: 79000000
# On sequence: 80000000
# On sequence: 81000000
# On sequence: 82000000
# On sequence: 83000000
# On sequence: 84000000
# On sequence: 85000000
# On sequence: 86000000
# On sequence: 87000000
# On sequence: 88000000
# On sequence: 89000000
# On sequence: 90000000
# On sequence: 91000000
# On sequence: 92000000
# On sequence: 93000000
# On sequence: 94000000
# On sequence: 95000000
# On sequence: 96000000
# On sequence: 97000000
# On sequence: 98000000
# On sequence: 99000000
# On sequence: 100000000
# On sequence: 101000000
# On sequence: 102000000
# On sequence: 103000000
# On sequence: 104000000
# On sequence: 105000000
# On sequence: 106000000
# On sequence: 107000000
# On sequence: 108000000
# On sequence: 109000000
# On sequence: 110000000
# On sequence: 111000000
# On sequence: 112000000
# On sequence: 113000000
# On sequence: 114000000
# On sequence: 115000000
# On sequence: 116000000
# On sequence: 117000000
# On sequence: 118000000
# On sequence: 119000000
# On sequence: 120000000
# On sequence: 121000000
# On sequence: 122000000
# On sequence: 123000000
# On sequence: 124000000
# On sequence: 125000000
# On sequence: 126000000
# On sequence: 127000000
# On sequence: 128000000
# On sequence: 129000000
# On sequence: 130000000
# On sequence: 131000000
# On sequence: 132000000
# Made one fastq file for each sequence length:
# Input file: /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/Ptiwi09_RIP_Early.fastq
# Example output filename: /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/Ptiwi09_RIP_Early25bp25bp.fastq
# Number of lines in input file: 529756000

# %%
# define variables:
# cell 1
forward = ['Ptiwi09_RIP_Early25bp25bp.fastq.gz']
reverse = ['']
#forward = ['H3K4me3_Rep1_R1.fastq.gz', 'H3K4me3_Rep2_R1.fastq.gz', 'H3K9me3_Rep1_R1.fastq.gz', 'H3K9me3_Rep2_R1.fastq.gz', 'H3K27me3_Rep1_R1.fastq.gz', 'H3K27me3_Rep2_R1.fastq.gz']
#reverse = ['H3K4me3_Rep1_R2.fastq.gz', 'H3K4me3_Rep2_R2.fastq.gz', 'H3K9me3_Rep1_R2.fastq.gz', 'H3K9me3_Rep2_R2.fastq.gz', 'H3K27me3_Rep1_R2.fastq.gz', 'H3K27me3_Rep2_R2.fastq.gz']
directory='/media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES'
cleanreads=False  # are .fastq.gz reads already clean? if True skip fastp
paired=False
reference='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES'

skipsteps=[]
hisat_args='-p 2 --no-softclip --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'

# %%
#fileextension='.fastq.gz'
#directory='/media/sf_LinuxShare/Projects/Ryuma/hisat2/2018-09-19_L1-4_ADPF-29_inserts'
#cleanreads=True  # are .fastq.gz reads already clean? if True skip fastp
#reference='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac'
print(datetime.datetime.now())

ReadMapping_v2.main(forward, reverse, directory, hisat_args, skipsteps, paired, reference)

print(datetime.datetime.now())
# Out:
# 2021-01-21 18:37:27.238867
# Start trimming of:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/Ptiwi09_RIP_Early25bp25bp.fastq.gz
#
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp  Created
# fastp -i /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/Ptiwi09_RIP_Early25bp25bp.fastq.gz -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/Ptiwi09_RIP_Early25bp25bp.trim.fastq.gz
# b''
# Finished trimming, files output to:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/Ptiwi09_RIP_Early25bp25bp.trim.fastq.gz
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/Ptiwi09_RIP_Early25bp25bp.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/Ptiwi09_RIP_Early25bp25bp.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/Ptiwi09_RIP_Early25bp25bp.trim.fastq
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/fastqc
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/fastqc  Created
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/Ptiwi09_RIP_Early25bp25bp.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/fastqc
#
# Aligning reads to Reference:
# /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/hisat2  Created
# Starting Hisat2 single end: aligning
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/Ptiwi09_RIP_Early25bp25bp.trim.fastq.gz
# hisat2 -q -p 2 --no-softclip --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv -x /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES -U /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/Ptiwi09_RIP_Early25bp25bp.trim.fastq.gz -S /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/hisat2/Ptiwi09_RIP_Early25bp25bp.trim.Pt_51_MacAndIES.sam
# Finished with Hisat2
#
# Starting samtools converting sam to sorted indexed bam
# Finished with Samtools, returning /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt09_RIP/Early/Pt_51_MacAndIES/fastp/hisat2/Ptiwi09_RIP_Early25bp25bp.trim.Pt_51_MacAndIES.sort.bam
#
# ##########
# ###FIN####
# ##########
# 2021-01-21 19:30:43.411441

# %%
# define variables:
# cell 1
forward = ['Ptiwi0109KD_total_sRNA_Early25bp25bp.fastq.gz']
reverse = ['']
#forward = ['H3K4me3_Rep1_R1.fastq.gz', 'H3K4me3_Rep2_R1.fastq.gz', 'H3K9me3_Rep1_R1.fastq.gz', 'H3K9me3_Rep2_R1.fastq.gz', 'H3K27me3_Rep1_R1.fastq.gz', 'H3K27me3_Rep2_R1.fastq.gz']
#reverse = ['H3K4me3_Rep1_R2.fastq.gz', 'H3K4me3_Rep2_R2.fastq.gz', 'H3K9me3_Rep1_R2.fastq.gz', 'H3K9me3_Rep2_R2.fastq.gz', 'H3K27me3_Rep1_R2.fastq.gz', 'H3K27me3_Rep2_R2.fastq.gz']
directory='/media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES'
cleanreads=False  # are .fastq.gz reads already clean? if True skip fastp
paired=False
reference='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES'

skipsteps=[]
hisat_args='-p 2 --no-softclip --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv'

# %%
#fileextension='.fastq.gz'
#directory='/media/sf_LinuxShare/Projects/Ryuma/hisat2/2018-09-19_L1-4_ADPF-29_inserts'
#cleanreads=True  # are .fastq.gz reads already clean? if True skip fastp
#reference='/media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_Mac'
print(datetime.datetime.now())

ReadMapping_v2.main(forward, reverse, directory, hisat_args, skipsteps, paired, reference)

print(datetime.datetime.now())
# Out:
# 2021-01-21 19:30:43.486899
# Start trimming of:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/Ptiwi0109KD_total_sRNA_Early25bp25bp.fastq.gz
#
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp  Created
# fastp -i /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/Ptiwi0109KD_total_sRNA_Early25bp25bp.fastq.gz -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/Ptiwi0109KD_total_sRNA_Early25bp25bp.trim.fastq.gz
# b''
# Finished trimming, files output to:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/Ptiwi0109KD_total_sRNA_Early25bp25bp.trim.fastq.gz
#
# Start unpacking trimmed.gz file:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/Ptiwi0109KD_total_sRNA_Early25bp25bp.trim.fastq.gz
# gzip -f -d -k /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/Ptiwi0109KD_total_sRNA_Early25bp25bp.trim.fastq.gz
# Finished unpacking:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/Ptiwi0109KD_total_sRNA_Early25bp25bp.trim.fastq
#
# Starting fastqc
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/fastqc
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/fastqc  Created
# /media/sf_LinuxShare/Programs/FastQC/fastqc -o /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/fastqc -f fastq fastq /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/Ptiwi0109KD_total_sRNA_Early25bp25bp.trim.fastq
# Finished fastqc, output at directory:
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/fastqc
#
# Aligning reads to Reference:
# /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES
# Directory  /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/hisat2  Created
# Starting Hisat2 single end: aligning
# /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/Ptiwi0109KD_total_sRNA_Early25bp25bp.trim.fastq.gz
# hisat2 -q -p 2 --no-softclip --pen-noncansplice 0 --known-splicesite-infile /media/sf_LinuxShare/Ciliates/Genomes/Annotations/ss.IES.pt_51_MacAndIES.tsv -x /media/sf_LinuxShare/Ciliates/Genomes/Hisat2_Indexes/Pt_51_MacAndIES -U /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/Ptiwi0109KD_total_sRNA_Early25bp25bp.trim.fastq.gz -S /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/hisat2/Ptiwi0109KD_total_sRNA_Early25bp25bp.trim.Pt_51_MacAndIES.sam
# Finished with Hisat2
#
# Starting samtools converting sam to sorted indexed bam
# Finished with Samtools, returning /media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt0109KD_Total_sRNA/Early/Pt_51_MacAndIES/fastp/hisat2/Ptiwi0109KD_total_sRNA_Early25bp25bp.trim.Pt_51_MacAndIES.sort.bam
#
# ##########
# ###FIN####
# ##########
# 2021-01-21 19:35:07.617522
